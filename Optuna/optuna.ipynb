# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import random_split, DataLoader, Subset
from torch.nn import functional as F
import torchvision
from torchvision import datasets, transforms
import torchvision.transforms as transforms
import optuna
import os

from sklearn.model_selection import KFold

print(torch.__version__)
# Out:
# 2.5.1

# %%
# Define relevant variables for the ML task
num_classes = 10
# Device will determine whether to run the training on GPU or CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Define the Dataset and Transformations

# %%
# Train transformations for augmenting training data
train_transforms = transforms.Compose([
    transforms.Resize((32, 32)),  # Resize all images to a fixed size of 32x32 pixels, as LeNet requires consistent input dimensions.
    transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally with a probability of 0.5 to increase dataset diversity.
    transforms.RandomRotation(10),  # Randomly rotate the image by up to ±10 degrees to simulate real-world variations in orientation.
    transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),  # Apply random affine transformations including shearing (up to ±10 degrees) and scaling (randomly resize within 80%-120%).
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor and normalize the pixel values to a range [0, 1].
    transforms.Normalize((0.5,), (0.5,)),  # Normalize the tensor values to have mean 0 and standard deviation 1 based on the specified mean and std (applied channel-wise).
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2)  # Introduce random changes in brightness, contrast, saturation, and hue to create variability in lighting conditions.
])

# Test transformations to process test data consistently with the model's expectations
test_transforms = transforms.Compose([
    transforms.Resize((32, 32)),  # Resize all test images to a fixed size of 32x32 pixels for compatibility with the model.
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor and scale pixel values to [0, 1].
    transforms.Normalize((0.5,), (0.5,))  # Normalize the test tensor values using mean 0 and std 1 to align with the training data input.
])

# Dataset initialization
dataset = torchvision.datasets.MNIST(
    root='./data',  # Path to the directory where the dataset should be downloaded or found.
    train=True,  # Indicates that we want to load the training set. If set to False, it would load the test set.
    transform=train_transforms,  # Apply the defined transformations to preprocess the training data.
    download=True  # Ensure the dataset is downloaded from the source if it's not already present in the specified directory.
    # This is useful to automatically fetch the MNIST dataset the first time the script is run.
)

# %% [markdown]
# # Define Model

# %%
class LeNet(nn.Module):
    """
    Implementation of the LeNet model for image classification.
    LeNet is a classic Convolutional Neural Network (CNN) architecture,
    which consists of convolutional layers for feature extraction,
    activation functions for introducing non-linearity, pooling layers for
    dimensionality reduction, and fully connected layers for the final classification.

    Key components:
    - Convolutional layers: Learn spatial hierarchies of features in the data.
    - BatchNormalization: Stabilizes and accelerates training.
    - Activation functions: Introduce non-linearity to the network.
    - MaxPooling: Reduces spatial dimensions and helps prevent overfitting.
    - Fully connected layers: Perform the classification task.
    """
    def __init__(self, num_classes, fc1_size, fc2_size):
        """
        Initializes the LeNet model with configurable fully connected layer sizes.

        Args:
        - num_classes (int): The number of output classes for classification.
        - fc1_size (int): The number of neurons in the first fully connected layer.
        - fc2_size (int): The number of neurons in the second fully connected layer.
        """
        super(LeNet, self).__init__()

        # First convolutional layer
        self.conv1 = nn.Conv2d(
            in_channels=1,  # Input has 1 channel (grayscale image)
            out_channels=6,  # Output has 6 feature maps
            kernel_size=5,  # Kernel size is 5x5
            stride=1,  # Stride of 1 (no skipping)
            padding=0  # No padding applied
        )
        self.relu1 = nn.ReLU()  # Activation function (ReLU) adds non-linearity
        self.bn1 = nn.BatchNorm2d(6)  # Batch normalization to stabilize and improve convergence

        # Second convolutional layer
        self.conv2 = nn.Conv2d(
            in_channels=6,  # Input has 6 feature maps from conv1
            out_channels=16,  # Output has 16 feature maps
            kernel_size=5,  # Kernel size is 5x5
            stride=1,  # Stride of 1
            padding=0  # No padding
        )
        self.relu2 = nn.ReLU()  # Activation function (ReLU) adds non-linearity
        self.bn2 = nn.BatchNorm2d(16)  # Batch normalization after second activation

        # Fully connected (dense) layers
        self.fc1 = nn.Linear(
            in_features=16 * 5 * 5,  # Input size after flattening (16 feature maps of size 5x5)
            out_features=fc1_size  # Number of neurons in first fully connected layer
        )
        self.relu3 = nn.ReLU()  # Activation function (ReLU) introduces non-linearity

        self.fc2 = nn.Linear(
            in_features=fc1_size,  # Input size is the output from the first FC layer
            out_features=fc2_size  # Number of neurons in second fully connected layer
        )
        self.relu4 = nn.ReLU()  # Activation function (ReLU) introduces non-linearity

        self.fc3 = nn.Linear(
            in_features=fc2_size,  # Input size is the output from the second FC layer
            out_features=num_classes  # Number of output classes for classification
        )
        # No activation (e.g., softmax) here because CrossEntropyLoss expects raw logits.

    def forward(self, x):
        """
        Defines the forward pass for the LeNet model.

        Args:
        - x (Tensor): Input tensor representing the batch of images.

        Returns:
        - x (Tensor): The raw logits corresponding to the classification outputs.
        """
        # Apply the first convolutional layer, activation, batch normalization, and max pooling
        x = self.conv1(x)  # Convolution operation
        x = self.relu1(x)  # Apply ReLU activation
        x = self.bn1(x)  # Batch normalization
        x = F.max_pool2d(x, kernel_size=2, stride=2)  # Using max pooling (2x2) to reduce spatial dimensions

        # Apply the second convolutional layer, activation, batch normalization, and max pooling
        x = self.conv2(x)  # Convolution operation
        x = self.relu2(x)  # Apply ReLU activation
        x = self.bn2(x)  # Batch normalization
        x = F.max_pool2d(x, kernel_size=2, stride=2)  # Using max pooling (2x2) to reduce spatial dimensions

        # Flatten the feature maps into a 1D feature vector for input to fully connected layers
        x = x.reshape(x.size(0), -1)  # Reshape to (batch_size, num_features)

        # Pass through the first fully connected layer and activation function
        x = self.fc1(x)  # Fully connected operation
        x = self.relu3(x)  # Apply ReLU activation

        # Pass through the second fully connected layer and activation function
        x = self.fc2(x)  # Fully connected operation
        x = self.relu4(x)  # Apply ReLU activation

        # Pass through the final fully connected layer to produce raw logits
        x = self.fc3(x)  # Fully connected operation (output layer)
        return x  # Return raw logits for use with CrossEntropyLoss

# %%
# model = LeNet(num_classes).to(device)
# input_size = (1, 32, 32)
# with torch.no_grad():
#     x = model.conv1(torch.randn(1, *input_size).to(device))
#     x = F.max_pool2d(x, kernel_size=2, stride=2)
#     x = model.conv2(x)
#     x = F.max_pool2d(x, kernel_size=2, stride=2)
#     print(x.shape)
#     print(16 * 5 *5)

# %% [markdown]
# # Implement K-Fold Cross Validation

# %%
CONFIG = {
    'k_folds': 5,  # Number of folds for K-Fold Cross Validation. This determines how the dataset will be split into training and validation subsets.
    'batch_size': 64,  # Batch size for training, which defines how many samples are processed before updating the model.
    'num_epochs': 10,  # Number of complete passes through the training dataset.
    'learning_rate': 0.001,  # Initial learning rate for the optimizer to control the step size in parameter updates.
}

DEFAULT_SUGGEST_PARAMS = {
    'fc1_range': (64, 256, 32),  # Range for the size of the first fully connected layer. Suggested as multiples of 32 between 64 and 256.
    'fc2_range': (32, 128, 16),  # Range for the size of the second fully connected layer. Suggested as multiples of 16 between 32 and 128.
    'batch_size_range': (32, 256, 32),  # Range for batch size suggestions. Suggested as multiples of 32 between 32 and 256.
    'learning_rate_range': (1e-5, 1e-1),  # Logarithmic range for suggesting learning rates between 1e-5 and 1e-1.
    'optimizers': ['Adam', 'SGD', 'Adadelta', 'Adagrad', 'RMSprop'],  # List of optimizers to choose from for training the model.
}

# %%
def initialize_training_pipeline(trial, num_classes, device, suggest_params=DEFAULT_SUGGEST_PARAMS):
    """
    Initializes the training pipeline by setting up the model, optimizer, criterion,
    and batch size based on parameters suggested by the Optuna trial object.

    Args:
    - trial (optuna.trial.Trial): The trial object that Optuna uses to suggest hyperparameter values.
    - num_classes (int): The number of classes for the classification task.
    - device (torch.device): The device (CPU or GPU) where the model and tensors will reside.
    - suggest_params (dict): A dictionary containing ranges and options for hyperparameter suggestions.

    Returns:
    - model (torch.nn.Module): The initialized model with suggested architecture based on trial.
    - optimizer (torch.optim.Optimizer): The optimizer selected and initialized with suggested learning rate.
    - criterion (torch.nn.Module): The loss function used for training the model.
    - batch_size (int): The batch size suggested for loading data during training.
    """

    # Suggest the size of the first fully connected layer (fc1) using a defined range.
    # Optuna uses this suggestion to explore different values to optimize the model's performance.
    # `trial.suggest_int` ensures that fc1_size is an integer.
    fc1_size = trial.suggest_int('fc1_size', low=suggest_params['fc1_range'][0], high=suggest_params['fc1_range'][1], step=suggest_params['fc1_range'][2])

    # Suggest the size of the second fully connected layer (fc2) using a defined range.
    # This allows for flexibility in adjusting the model's capacity.
    fc2_size = trial.suggest_int('fc2_size', low=suggest_params['fc2_range'][0], high=suggest_params['fc2_range'][1], step=suggest_params['fc2_range'][2])

    # Initialize the model with the suggested layer sizes and number of output classes (num_classes).
    # The model is moved to the specified device (GPU or CPU).
    model = LeNet(num_classes, fc1_size, fc2_size).to(device)

    # Suggest an optimizer from a predefined list.
    # Different optimizers may perform better depending on the training task and dataset.
    optimizer_name = trial.suggest_categorical('optimizer', suggest_params['optimizers'])

    # Suggest a learning rate in a logarithmic scale (log=True).
    # This helps explore a wide range of values for the learning rate.
    learning_rate = trial.suggest_float('lr', *suggest_params['learning_rate_range'], log=True)

    # Initialize the optimizer with the suggested learning rate and optimizer type.
    # The `getattr` function retrieves the optimizer from the PyTorch `optim` module.
    optimizer = getattr(optim, optimizer_name)(model.parameters(), lr=learning_rate)

    # Suggest a batch size for data loading from a defined range.
    # Batch size affects the memory usage and stability of the training process.
    batch_size = trial.suggest_int('batch_size', low=suggest_params['batch_size_range'][0], high=suggest_params['batch_size_range'][1], step=suggest_params['batch_size_range'][2])

    # Define the loss function for classification.
    # CrossEntropyLoss is commonly used for multi-class classification problems.
    criterion = nn.CrossEntropyLoss()

    # Return the initialized model, optimizer, loss function, and batch size.
    return model, optimizer, criterion, batch_size

# %%
# This function calculates average metrics (loss and accuracy) based on the provided lists of values.
# It takes two input parameters:
# - losses: A list of numeric values representing loss metrics.
# - accuracies: A list of numeric values representing accuracy metrics.
# The function computes the arithmetic mean of the values in each list and returns the results as a tuple.
def calculate_metrics(losses, accuracies):
    avg_loss = sum(losses) / len(losses)
    avg_accuracy = sum(accuracies) / len(accuracies)
    return avg_loss, avg_accuracy

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, device):
    """
    Trains the model for one complete pass (epoch) over the provided training data.

    Args:
    - model (torch.nn.Module): The neural network model to train.
    - train_loader (torch.utils.data.DataLoader): The DataLoader that provides batches of training data.
    - criterion (torch.nn.Module): The loss function used to calculate the difference between predictions and targets.
    - optimizer (torch.optim.Optimizer): The optimizer responsible for updating the model's parameters.
    - device (torch.device): The device on which calculations will be performed (CPU or GPU).

    Returns:
    - avg_loss (float): The average loss across all training batches.
    - accuracy (float): The overall accuracy of the model on the training dataset.
    """
    model.train()  # Sets the model to training mode (enables features like dropout, batchnorm updates).
    total_loss, correct = 0.0, 0  # Initialize counters for total loss and total correct predictions.

    # Iterate through training data in batches
    for data, target in train_loader:
        # Move data and labels to the specified device (e.g., GPU for faster computations).
        data, target = data.to(device), target.to(device)

        # Perform a forward pass to get the model's predictions.
        output = model(data)

        # Compute the loss for the current batch using the criterion (e.g., CrossEntropyLoss).
        loss = criterion(output, target)

        # Zero the gradients of the optimizer to prevent accumulation from previous steps.
        optimizer.zero_grad()

        # Perform backpropagation to compute gradients for the model's parameters.
        loss.backward()

        # Update the model's parameters using the computed gradients.
        optimizer.step()

        # Accumulate the current batch's loss to the total_loss.
        total_loss += loss.item()

        # Determine the predicted class for each example in the batch.
        pred = output.argmax(dim=1)

        # Count the number of correct predictions by comparing with the true labels.
        correct += pred.eq(target).sum().item()

    # Calculate the average loss across all training batches.
    avg_loss = total_loss / len(train_loader)

    # Calculate the accuracy as the fraction of correct predictions over the total dataset.
    accuracy = correct / len(train_loader.dataset)

    # Return the average loss and accuracy for this epoch.
    return avg_loss, accuracy

# %%
def validate(model, val_loader, criterion, device):
    """
    Evaluates the model on the validation dataset to calculate the average loss and accuracy.

    Args:
    - model (torch.nn.Module): The trained neural network model to evaluate.
    - val_loader (torch.utils.data.DataLoader): DataLoader for the validation dataset.
    - criterion (torch.nn.Module): The loss function used to calculate the loss between predictions and targets.
    - device (torch.device): The device (e.g., CPU or GPU) where computations will take place.

    Returns:
    - avg_loss (float): The average loss over all validation batches.
    - accuracy (float): The overall accuracy of the model on the validation dataset.
    """

    # Set the model to evaluation mode, which disables certain behaviors like dropout to ensure consistent results.
    model.eval()

    # Initialize total variables to calculate cumulative loss and correct predictions.
    total_loss, correct = 0.0, 0

    # Disable gradient computation since the model is in evaluation mode to save memory and computation.
    with torch.no_grad():
        # Iterate over the validation dataset in batches
        for data, target in val_loader:
            # Move the input data and labels to the specified device (e.g., GPU for faster computation).
            data, target = data.to(device), target.to(device)

            # Perform a forward pass to get predictions from the model.
            output = model(data)

            # Compute the loss for the current batch.
            total_loss += criterion(output, target).item()

            # Get the predicted class for each input by finding the index of the maximum value along the last dimension.
            pred = output.argmax(dim=1, keepdim=True)

            # Increment the total count of correct predictions by comparing the predictions with the true labels.
            correct += pred.eq(target.view_as(pred)).sum().item()

    # Calculate the average loss by dividing the total loss by the number of validation batches.
    avg_loss = total_loss / len(val_loader)

    # Calculate the accuracy by dividing the number of correct predictions by the total number of samples in the dataset.
    accuracy = correct / len(val_loader.dataset)

    # Return the average loss and the accuracy.
    return avg_loss, accuracy

# %%
# Initialize empty lists to track losses and accuracies for both training and validation
train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []

# Set up K-Fold Cross Validation with the number of splits from the CONFIG and shuffle enabled
kfold = KFold(n_splits=CONFIG['k_folds'], shuffle=True)


def objective(trial):
    """
    The objective function used in Optuna for hyperparameter optimization.

    Args:
    - trial: Optuna trial object that suggests hyperparameter values.

    Returns:
    - Average validation accuracy across all folds for the given trial's hyperparameter configuration.
    """
    try:
        # Initialize the training pipeline with the trial suggesting hyperparameters
        # This function should return the model, optimizer, criterion, and batch size
        model, optimizer, criterion, batch_size = initialize_training_pipeline(trial, num_classes, device)

        # Reinitialize K-Fold Cross Validation for the dataset splitting
        kfold = KFold(n_splits=CONFIG['k_folds'], shuffle=True)

        # Total validation accuracy to calculate the average later
        total_val_acc = 0.0

        # Loop through each fold in the k-fold cross-validation process
        for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset)):
            print(f'Fold {fold + 1}')  # Print current fold number

            # Split dataset into training and validation subsets for the current fold
            train_subset, val_subset = Subset(dataset, train_idx), Subset(dataset, val_idx)

            # Create DataLoaders for training and validation subsets
            train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)  # Shuffle training data
            val_loader = DataLoader(val_subset, batch_size=batch_size)  # No shuffle for validation data

            # Loop for each epoch within the current fold
            for epoch in range(CONFIG["num_epochs"]):
                print(f'Epoch {epoch + 1}')  # Print current epoch number

                # Perform one epoch of training and return the loss and accuracy
                train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)

                # Perform validation and return the loss and accuracy
                val_loss, val_acc = validate(model, val_loader, criterion, device)

                # Accumulate validation accuracy for calculating average
                total_val_acc += val_acc

                # Record losses and accuracies for analysis
                train_losses.append(train_loss)
                train_accuracies.append(train_acc)
                val_losses.append(val_loss)
                val_accuracies.append(val_acc)

                # Print the current training and validation performance
                print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')
                print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        # Calculate average metrics for the entire training and validation process
        avg_train_loss, avg_train_acc = calculate_metrics(train_losses, train_accuracies)
        avg_val_loss, avg_val_acc = calculate_metrics(val_losses, val_accuracies)

        # Display the average metrics for this trial
        print(f'Average Train Loss: {avg_train_loss:.4f}, Average Train Acc: {avg_train_acc:.4f}')
        print(f'Average Val Loss: {avg_val_loss:.4f}, Average Val Acc: {avg_val_acc:.4f}')

        # Return the average validation accuracy normalized to the range [0,1]
        return total_val_acc / (CONFIG['k_folds'] * 100)

    except Exception as e:
        # Handle and log any exceptions that occur during the trial execution
        # Returning infinity ensures that this trial is considered poorly performing and not selected
        print(f"Trial failed due to: {str(e)}")
        # Check the optimization direction of the study
        if study.direction == 'maximize':
            return -float('inf')  # Very poor outcome for maximization
        else:
            return float('inf')  # Very poor outcome for minimization

# %%
# Create an Optuna study to perform hyperparameter optimization. The objective is set to minimize a metric.
study = optuna.create_study(direction='maximize')

# Set the logging level for Optuna to DEBUG to output detailed information during the optimization process.
optuna.logging.set_verbosity(optuna.logging.DEBUG)

# Run the optimization process using the defined objective function with 20 trials.
study.optimize(objective, n_trials=20)

# Check if there are any completed trials and whether the study has a valid best trial.
if len(study.trials) > 0 and study.best_trial is not None:
    # Retrieve the best trial from the study and print its objective value and hyperparameters.
    trial = study.best_trial
    print('Best objective value: {}'.format(trial.value))
    print('Best hyperparameters: {}'.format(trial.params))
else:
    # Notify the user that no trials have completed successfully. The objective function might need fixing.
    print("No trials completed successfully. Please check your objective function.")
# Out:
# [I 2025-02-16 22:20:23,792] A new study created in memory with name: no-name-5f7412a1-4258-4982-bdeb-3fda3e113523
# Fold 1
# Epoch 1
# Train Loss: 1.7614, Train Acc: 0.5016
# Val Loss: 1.0796, Val Acc: 0.7172
# Epoch 2
# Train Loss: 0.7915, Train Acc: 0.7713
# Val Loss: 0.6304, Val Acc: 0.8061
# Epoch 3
# Train Loss: 0.5562, Train Acc: 0.8297
# Val Loss: 0.5007, Val Acc: 0.8426
# Epoch 4
# Train Loss: 0.4540, Train Acc: 0.8597
# Val Loss: 0.4192, Val Acc: 0.8683
# Epoch 5
# Train Loss: 0.3891, Train Acc: 0.8805
# Val Loss: 0.3709, Val Acc: 0.8861
# Epoch 6
# Train Loss: 0.3492, Train Acc: 0.8914
# Val Loss: 0.3290, Val Acc: 0.8993
# Epoch 7
# Train Loss: 0.3122, Train Acc: 0.9031
# Val Loss: 0.3035, Val Acc: 0.9072
# Epoch 8
# Train Loss: 0.2886, Train Acc: 0.9119
# Val Loss: 0.2793, Val Acc: 0.9142
# Epoch 9
# Train Loss: 0.2674, Train Acc: 0.9173
# Val Loss: 0.2590, Val Acc: 0.9175
# Epoch 10
# Train Loss: 0.2520, Train Acc: 0.9230
# Val Loss: 0.2499, Val Acc: 0.9237
# Fold 2
# Epoch 1
# Train Loss: 0.2374, Train Acc: 0.9275
# Val Loss: 0.2430, Val Acc: 0.9259
# Epoch 2
# Train Loss: 0.2267, Train Acc: 0.9295
# Val Loss: 0.2357, Val Acc: 0.9265
# Epoch 3
# Train Loss: 0.2131, Train Acc: 0.9336
# Val Loss: 0.2278, Val Acc: 0.9313
# Epoch 4
# Train Loss: 0.2100, Train Acc: 0.9343
# Val Loss: 0.2222, Val Acc: 0.9289
# Epoch 5
# Train Loss: 0.2018, Train Acc: 0.9377
# Val Loss: 0.2155, Val Acc: 0.9313
# Epoch 6
# Train Loss: 0.1924, Train Acc: 0.9396
# Val Loss: 0.2011, Val Acc: 0.9383
# Epoch 7
# Train Loss: 0.1891, Train Acc: 0.9403
# Val Loss: 0.1957, Val Acc: 0.9388
# Epoch 8
# Train Loss: 0.1827, Train Acc: 0.9419
# Val Loss: 0.1915, Val Acc: 0.9401
# Epoch 9
# Train Loss: 0.1767, Train Acc: 0.9444
# Val Loss: 0.1887, Val Acc: 0.9420
# Epoch 10
# Train Loss: 0.1702, Train Acc: 0.9467
# Val Loss: 0.1868, Val Acc: 0.9416
# Fold 3
# Epoch 1
# Train Loss: 0.1726, Train Acc: 0.9460
# Val Loss: 0.1566, Val Acc: 0.9507
# Epoch 2
# Train Loss: 0.1670, Train Acc: 0.9475
# Val Loss: 0.1551, Val Acc: 0.9504
# Epoch 3
# Train Loss: 0.1662, Train Acc: 0.9494
# Val Loss: 0.1568, Val Acc: 0.9517
# Epoch 4
# Train Loss: 0.1615, Train Acc: 0.9498
# Val Loss: 0.1496, Val Acc: 0.9522
# Epoch 5
# Train Loss: 0.1579, Train Acc: 0.9516
# Val Loss: 0.1446, Val Acc: 0.9545
# Epoch 6
# Train Loss: 0.1527, Train Acc: 0.9520
# Val Loss: 0.1449, Val Acc: 0.9547
# Epoch 7
# Train Loss: 0.1507, Train Acc: 0.9531
# Val Loss: 0.1436, Val Acc: 0.9550
# Epoch 8
# Train Loss: 0.1507, Train Acc: 0.9532
# Val Loss: 0.1431, Val Acc: 0.9527
# Epoch 9
# Train Loss: 0.1465, Train Acc: 0.9546
# Val Loss: 0.1375, Val Acc: 0.9580
# Epoch 10
# Train Loss: 0.1410, Train Acc: 0.9565
# Val Loss: 0.1398, Val Acc: 0.9548
# Fold 4
# Epoch 1
# Train Loss: 0.1419, Train Acc: 0.9556
# Val Loss: 0.1283, Val Acc: 0.9584
# Epoch 2
# Train Loss: 0.1430, Train Acc: 0.9561
# Val Loss: 0.1295, Val Acc: 0.9603
# Epoch 3
# Train Loss: 0.1374, Train Acc: 0.9570
# Val Loss: 0.1270, Val Acc: 0.9597
# Epoch 4
# Train Loss: 0.1339, Train Acc: 0.9582
# Val Loss: 0.1257, Val Acc: 0.9587
# Epoch 5
# Train Loss: 0.1352, Train Acc: 0.9569
# Val Loss: 0.1219, Val Acc: 0.9622
# Epoch 6
# Train Loss: 0.1298, Train Acc: 0.9590
# Val Loss: 0.1220, Val Acc: 0.9617
# Epoch 7
# Train Loss: 0.1298, Train Acc: 0.9596
# Val Loss: 0.1245, Val Acc: 0.9606
# Epoch 8
# Train Loss: 0.1284, Train Acc: 0.9609
# Val Loss: 0.1193, Val Acc: 0.9623
# Epoch 9
# Train Loss: 0.1255, Train Acc: 0.9604
# Val Loss: 0.1173, Val Acc: 0.9618
# Epoch 10
# Train Loss: 0.1235, Train Acc: 0.9620
# Val Loss: 0.1146, Val Acc: 0.9632
# Fold 5
# Epoch 1
# Train Loss: 0.1208, Train Acc: 0.9613
# Val Loss: 0.1223, Val Acc: 0.9626
# Epoch 2
# Train Loss: 0.1181, Train Acc: 0.9621
# Val Loss: 0.1228, Val Acc: 0.9620
# Epoch 3
# Train Loss: 0.1172, Train Acc: 0.9631
# Val Loss: 0.1191, Val Acc: 0.9640
# Epoch 4
# Train Loss: 0.1151, Train Acc: 0.9641
# Val Loss: 0.1212, Val Acc: 0.9635
# Epoch 5
# Train Loss: 0.1156, Train Acc: 0.9622
# Val Loss: 0.1211, Val Acc: 0.9646
# Epoch 6
# Train Loss: 0.1119, Train Acc: 0.9647
# Val Loss: 0.1118, Val Acc: 0.9682
# Epoch 7
# Train Loss: 0.1110, Train Acc: 0.9642
# Val Loss: 0.1188, Val Acc: 0.9615
# Epoch 8
# Train Loss: 0.1087, Train Acc: 0.9659
# Val Loss: 0.1165, Val Acc: 0.9647
# Epoch 9
# Train Loss: 0.1091, Train Acc: 0.9647
# Val Loss: 0.1143, Val Acc: 0.9653
# Epoch 10
# [I 2025-02-16 22:28:57,781] Trial 0 finished with value: 0.09362333333333331 and parameters: {'fc1_size': 160, 'fc2_size': 96, 'optimizer': 'Adam', 'lr': 5.071482846224742e-05, 'batch_size': 192}. Best is trial 0 with value: 0.09362333333333331.
# Train Loss: 0.1071, Train Acc: 0.9663
# Val Loss: 0.1141, Val Acc: 0.9651
# Average Train Loss: 0.2290, Average Train Acc: 0.9301
# Average Val Loss: 0.2083, Average Val Acc: 0.9362
# Fold 1
# Epoch 1
# Train Loss: 2.3100, Train Acc: 0.0891
# Val Loss: 2.3034, Val Acc: 0.0945
# Epoch 2
# Train Loss: 2.2981, Train Acc: 0.1010
# Val Loss: 2.2924, Val Acc: 0.1117
# Epoch 3
# Train Loss: 2.2866, Train Acc: 0.1210
# Val Loss: 2.2804, Val Acc: 0.1407
# Epoch 4
# Train Loss: 2.2756, Train Acc: 0.1517
# Val Loss: 2.2701, Val Acc: 0.1718
# Epoch 5
# Train Loss: 2.2645, Train Acc: 0.1851
# Val Loss: 2.2573, Val Acc: 0.2012
# Epoch 6
# Train Loss: 2.2525, Train Acc: 0.2154
# Val Loss: 2.2455, Val Acc: 0.2293
# Epoch 7
# Train Loss: 2.2403, Train Acc: 0.2438
# Val Loss: 2.2352, Val Acc: 0.2550
# Epoch 8
# Train Loss: 2.2281, Train Acc: 0.2693
# Val Loss: 2.2220, Val Acc: 0.2748
# Epoch 9
# Train Loss: 2.2147, Train Acc: 0.2925
# Val Loss: 2.2091, Val Acc: 0.3035
# Epoch 10
# Train Loss: 2.2005, Train Acc: 0.3190
# Val Loss: 2.1951, Val Acc: 0.3242
# Fold 2
# Epoch 1
# Train Loss: 2.1857, Train Acc: 0.3397
# Val Loss: 2.1777, Val Acc: 0.3482
# Epoch 2
# Train Loss: 2.1704, Train Acc: 0.3638
# Val Loss: 2.1616, Val Acc: 0.3771
# Epoch 3
# Train Loss: 2.1542, Train Acc: 0.3888
# Val Loss: 2.1453, Val Acc: 0.3986
# Epoch 4
# Train Loss: 2.1372, Train Acc: 0.4048
# Val Loss: 2.1251, Val Acc: 0.4219
# Epoch 5
# Train Loss: 2.1180, Train Acc: 0.4289
# Val Loss: 2.1056, Val Acc: 0.4437
# Epoch 6
# Train Loss: 2.0994, Train Acc: 0.4455
# Val Loss: 2.0897, Val Acc: 0.4550
# Epoch 7
# Train Loss: 2.0793, Train Acc: 0.4600
# Val Loss: 2.0667, Val Acc: 0.4617
# Epoch 8
# Train Loss: 2.0586, Train Acc: 0.4746
# Val Loss: 2.0460, Val Acc: 0.4837
# Epoch 9
# Train Loss: 2.0365, Train Acc: 0.4886
# Val Loss: 2.0258, Val Acc: 0.4884
# Epoch 10
# Train Loss: 2.0138, Train Acc: 0.4996
# Val Loss: 2.0020, Val Acc: 0.5035
# Fold 3
# Epoch 1
# Train Loss: 1.9929, Train Acc: 0.5068
# Val Loss: 1.9721, Val Acc: 0.5211
# Epoch 2
# Train Loss: 1.9688, Train Acc: 0.5152
# Val Loss: 1.9479, Val Acc: 0.5209
# Epoch 3
# Train Loss: 1.9457, Train Acc: 0.5227
# Val Loss: 1.9258, Val Acc: 0.5333
# Epoch 4
# Train Loss: 1.9208, Train Acc: 0.5321
# Val Loss: 1.9045, Val Acc: 0.5376
# Epoch 5
# Train Loss: 1.8967, Train Acc: 0.5409
# Val Loss: 1.8777, Val Acc: 0.5427
# Epoch 6
# Train Loss: 1.8729, Train Acc: 0.5489
# Val Loss: 1.8513, Val Acc: 0.5579
# Epoch 7
# Train Loss: 1.8473, Train Acc: 0.5565
# Val Loss: 1.8288, Val Acc: 0.5646
# Epoch 8
# Train Loss: 1.8211, Train Acc: 0.5641
# Val Loss: 1.8028, Val Acc: 0.5702
# Epoch 9
# Train Loss: 1.7958, Train Acc: 0.5743
# Val Loss: 1.7725, Val Acc: 0.5823
# Epoch 10
# Train Loss: 1.7710, Train Acc: 0.5794
# Val Loss: 1.7447, Val Acc: 0.5914
# Fold 4
# Epoch 1
# Train Loss: 1.7414, Train Acc: 0.5858
# Val Loss: 1.7415, Val Acc: 0.5871
# Epoch 2
# Train Loss: 1.7164, Train Acc: 0.5927
# Val Loss: 1.7089, Val Acc: 0.5981
# Epoch 3
# Train Loss: 1.6881, Train Acc: 0.6019
# Val Loss: 1.6822, Val Acc: 0.6040
# Epoch 4
# Train Loss: 1.6601, Train Acc: 0.6095
# Val Loss: 1.6563, Val Acc: 0.6098
# Epoch 5
# Train Loss: 1.6347, Train Acc: 0.6144
# Val Loss: 1.6250, Val Acc: 0.6167
# Epoch 6
# Train Loss: 1.6099, Train Acc: 0.6177
# Val Loss: 1.6020, Val Acc: 0.6187
# Epoch 7
# Train Loss: 1.5829, Train Acc: 0.6234
# Val Loss: 1.5810, Val Acc: 0.6267
# Epoch 8
# Train Loss: 1.5561, Train Acc: 0.6313
# Val Loss: 1.5523, Val Acc: 0.6281
# Epoch 9
# Train Loss: 1.5309, Train Acc: 0.6334
# Val Loss: 1.5216, Val Acc: 0.6400
# Epoch 10
# Train Loss: 1.5044, Train Acc: 0.6391
# Val Loss: 1.4969, Val Acc: 0.6384
# Fold 5
# Epoch 1
# Train Loss: 1.4799, Train Acc: 0.6435
# Val Loss: 1.4641, Val Acc: 0.6483
# Epoch 2
# Train Loss: 1.4513, Train Acc: 0.6490
# Val Loss: 1.4410, Val Acc: 0.6512
# Epoch 3
# Train Loss: 1.4268, Train Acc: 0.6544
# Val Loss: 1.4143, Val Acc: 0.6637
# Epoch 4
# Train Loss: 1.4012, Train Acc: 0.6594
# Val Loss: 1.3867, Val Acc: 0.6617
# Epoch 5
# Train Loss: 1.3761, Train Acc: 0.6653
# Val Loss: 1.3678, Val Acc: 0.6653
# Epoch 6
# Train Loss: 1.3513, Train Acc: 0.6665
# Val Loss: 1.3419, Val Acc: 0.6687
# Epoch 7
# Train Loss: 1.3287, Train Acc: 0.6731
# Val Loss: 1.3167, Val Acc: 0.6707
# Epoch 8
# Train Loss: 1.3051, Train Acc: 0.6765
# Val Loss: 1.2978, Val Acc: 0.6767
# Epoch 9
# Train Loss: 1.2816, Train Acc: 0.6807
# Val Loss: 1.2744, Val Acc: 0.6763
# Epoch 10
# [I 2025-02-16 22:37:36,457] Trial 1 finished with value: 0.04970433333333332 and parameters: {'fc1_size': 224, 'fc2_size': 112, 'optimizer': 'Adadelta', 'lr': 0.0003823923546226007, 'batch_size': 192}. Best is trial 0 with value: 0.09362333333333331.
# Train Loss: 1.2593, Train Acc: 0.6862
# Val Loss: 1.2495, Val Acc: 0.6918
# Average Train Loss: 1.0379, Average Train Acc: 0.7103
# Average Val Loss: 1.0222, Average Val Acc: 0.7166
# Fold 1
# Epoch 1
# Train Loss: 2.3197, Train Acc: 0.1103
# Val Loss: 2.3202, Val Acc: 0.1086
# Epoch 2
# Train Loss: 2.3168, Train Acc: 0.1114
# Val Loss: 2.3166, Val Acc: 0.1090
# Epoch 3
# Train Loss: 2.3150, Train Acc: 0.1116
# Val Loss: 2.3162, Val Acc: 0.1140
# Epoch 4
# Train Loss: 2.3124, Train Acc: 0.1151
# Val Loss: 2.3137, Val Acc: 0.1119
# Epoch 5
# Train Loss: 2.3097, Train Acc: 0.1152
# Val Loss: 2.3097, Val Acc: 0.1161
# Epoch 6
# Train Loss: 2.3080, Train Acc: 0.1185
# Val Loss: 2.3087, Val Acc: 0.1161
# Epoch 7
# Train Loss: 2.3053, Train Acc: 0.1198
# Val Loss: 2.3056, Val Acc: 0.1154
# Epoch 8
# Train Loss: 2.3030, Train Acc: 0.1195
# Val Loss: 2.3042, Val Acc: 0.1210
# Epoch 9
# Train Loss: 2.3016, Train Acc: 0.1209
# Val Loss: 2.3004, Val Acc: 0.1227
# Epoch 10
# Train Loss: 2.2984, Train Acc: 0.1239
# Val Loss: 2.3006, Val Acc: 0.1209
# Fold 2
# Epoch 1
# Train Loss: 2.2970, Train Acc: 0.1246
# Val Loss: 2.2956, Val Acc: 0.1278
# Epoch 2
# Train Loss: 2.2949, Train Acc: 0.1253
# Val Loss: 2.2925, Val Acc: 0.1288
# Epoch 3
# Train Loss: 2.2924, Train Acc: 0.1274
# Val Loss: 2.2906, Val Acc: 0.1317
# Epoch 4
# Train Loss: 2.2904, Train Acc: 0.1300
# Val Loss: 2.2885, Val Acc: 0.1317
# Epoch 5
# Train Loss: 2.2881, Train Acc: 0.1329
# Val Loss: 2.2861, Val Acc: 0.1378
# Epoch 6
# Train Loss: 2.2855, Train Acc: 0.1338
# Val Loss: 2.2845, Val Acc: 0.1328
# Epoch 7
# Train Loss: 2.2838, Train Acc: 0.1361
# Val Loss: 2.2815, Val Acc: 0.1393
# Epoch 8
# Train Loss: 2.2818, Train Acc: 0.1379
# Val Loss: 2.2790, Val Acc: 0.1448
# Epoch 9
# Train Loss: 2.2795, Train Acc: 0.1397
# Val Loss: 2.2786, Val Acc: 0.1443
# Epoch 10
# Train Loss: 2.2772, Train Acc: 0.1411
# Val Loss: 2.2751, Val Acc: 0.1457
# Fold 3
# Epoch 1
# Train Loss: 2.2751, Train Acc: 0.1477
# Val Loss: 2.2723, Val Acc: 0.1458
# Epoch 2
# Train Loss: 2.2735, Train Acc: 0.1505
# Val Loss: 2.2688, Val Acc: 0.1570
# Epoch 3
# Train Loss: 2.2719, Train Acc: 0.1498
# Val Loss: 2.2664, Val Acc: 0.1584
# Epoch 4
# Train Loss: 2.2689, Train Acc: 0.1579
# Val Loss: 2.2650, Val Acc: 0.1603
# Epoch 5
# Train Loss: 2.2661, Train Acc: 0.1594
# Val Loss: 2.2632, Val Acc: 0.1614
# Epoch 6
# Train Loss: 2.2635, Train Acc: 0.1646
# Val Loss: 2.2608, Val Acc: 0.1701
# Epoch 7
# Train Loss: 2.2617, Train Acc: 0.1672
# Val Loss: 2.2584, Val Acc: 0.1736
# Epoch 8
# Train Loss: 2.2597, Train Acc: 0.1701
# Val Loss: 2.2568, Val Acc: 0.1756
# Epoch 9
# Train Loss: 2.2575, Train Acc: 0.1746
# Val Loss: 2.2541, Val Acc: 0.1800
# Epoch 10
# Train Loss: 2.2550, Train Acc: 0.1807
# Val Loss: 2.2517, Val Acc: 0.1899
# Fold 4
# Epoch 1
# Train Loss: 2.2515, Train Acc: 0.1896
# Val Loss: 2.2511, Val Acc: 0.1907
# Epoch 2
# Train Loss: 2.2494, Train Acc: 0.1928
# Val Loss: 2.2495, Val Acc: 0.1964
# Epoch 3
# Train Loss: 2.2474, Train Acc: 0.2011
# Val Loss: 2.2465, Val Acc: 0.1993
# Epoch 4
# Train Loss: 2.2452, Train Acc: 0.2019
# Val Loss: 2.2444, Val Acc: 0.2062
# Epoch 5
# Train Loss: 2.2426, Train Acc: 0.2107
# Val Loss: 2.2420, Val Acc: 0.2109
# Epoch 6
# Train Loss: 2.2399, Train Acc: 0.2165
# Val Loss: 2.2389, Val Acc: 0.2151
# Epoch 7
# Train Loss: 2.2379, Train Acc: 0.2229
# Val Loss: 2.2373, Val Acc: 0.2340
# Epoch 8
# Train Loss: 2.2350, Train Acc: 0.2302
# Val Loss: 2.2342, Val Acc: 0.2354
# Epoch 9
# Train Loss: 2.2334, Train Acc: 0.2371
# Val Loss: 2.2319, Val Acc: 0.2430
# Epoch 10
# Train Loss: 2.2305, Train Acc: 0.2440
# Val Loss: 2.2290, Val Acc: 0.2458
# Fold 5
# Epoch 1
# Train Loss: 2.2274, Train Acc: 0.2560
# Val Loss: 2.2267, Val Acc: 0.2543
# Epoch 2
# Train Loss: 2.2250, Train Acc: 0.2597
# Val Loss: 2.2256, Val Acc: 0.2553
# Epoch 3
# Train Loss: 2.2228, Train Acc: 0.2685
# Val Loss: 2.2209, Val Acc: 0.2702
# Epoch 4
# Train Loss: 2.2196, Train Acc: 0.2772
# Val Loss: 2.2185, Val Acc: 0.2732
# Epoch 5
# Train Loss: 2.2170, Train Acc: 0.2854
# Val Loss: 2.2156, Val Acc: 0.2874
# Epoch 6
# Train Loss: 2.2143, Train Acc: 0.2934
# Val Loss: 2.2116, Val Acc: 0.2905
# Epoch 7
# Train Loss: 2.2115, Train Acc: 0.2982
# Val Loss: 2.2099, Val Acc: 0.2994
# Epoch 8
# Train Loss: 2.2088, Train Acc: 0.3086
# Val Loss: 2.2090, Val Acc: 0.3081
# Epoch 9
# Train Loss: 2.2057, Train Acc: 0.3154
# Val Loss: 2.2052, Val Acc: 0.3080
# Epoch 10
# [I 2025-02-16 22:46:12,919] Trial 2 finished with value: 0.018465500000000003 and parameters: {'fc1_size': 160, 'fc2_size': 128, 'optimizer': 'SGD', 'lr': 4.627122312842472e-05, 'batch_size': 224}. Best is trial 0 with value: 0.09362333333333331.
# Train Loss: 2.2031, Train Acc: 0.3215
# Val Loss: 2.2037, Val Acc: 0.3167
# Average Train Loss: 1.4465, Average Train Acc: 0.5345
# Average Val Loss: 1.4356, Average Val Acc: 0.5393
# Fold 1
# Epoch 1
# Train Loss: 0.6886, Train Acc: 0.7922
# Val Loss: 0.4561, Val Acc: 0.8598
# Epoch 2
# Train Loss: 0.4055, Train Acc: 0.8724
# Val Loss: 0.3698, Val Acc: 0.8884
# Epoch 3
# Train Loss: 0.3471, Train Acc: 0.8923
# Val Loss: 0.3287, Val Acc: 0.8991
# Epoch 4
# Train Loss: 0.3100, Train Acc: 0.9037
# Val Loss: 0.3032, Val Acc: 0.9051
# Epoch 5
# Train Loss: 0.2861, Train Acc: 0.9120
# Val Loss: 0.2782, Val Acc: 0.9149
# Epoch 6
# Train Loss: 0.2694, Train Acc: 0.9177
# Val Loss: 0.2611, Val Acc: 0.9194
# Epoch 7
# Train Loss: 0.2556, Train Acc: 0.9214
# Val Loss: 0.2475, Val Acc: 0.9243
# Epoch 8
# Train Loss: 0.2426, Train Acc: 0.9247
# Val Loss: 0.2360, Val Acc: 0.9295
# Epoch 9
# Train Loss: 0.2332, Train Acc: 0.9269
# Val Loss: 0.2256, Val Acc: 0.9327
# Epoch 10
# Train Loss: 0.2244, Train Acc: 0.9302
# Val Loss: 0.2231, Val Acc: 0.9333
# Fold 2
# Epoch 1
# Train Loss: 0.2189, Train Acc: 0.9332
# Val Loss: 0.2068, Val Acc: 0.9368
# Epoch 2
# Train Loss: 0.2113, Train Acc: 0.9349
# Val Loss: 0.2001, Val Acc: 0.9370
# Epoch 3
# Train Loss: 0.2097, Train Acc: 0.9361
# Val Loss: 0.1974, Val Acc: 0.9392
# Epoch 4
# Train Loss: 0.2056, Train Acc: 0.9371
# Val Loss: 0.1986, Val Acc: 0.9372
# Epoch 5
# Train Loss: 0.1978, Train Acc: 0.9393
# Val Loss: 0.1919, Val Acc: 0.9413
# Epoch 6
# Train Loss: 0.1921, Train Acc: 0.9407
# Val Loss: 0.1883, Val Acc: 0.9446
# Epoch 7
# Train Loss: 0.1894, Train Acc: 0.9420
# Val Loss: 0.1843, Val Acc: 0.9443
# Epoch 8
# Train Loss: 0.1853, Train Acc: 0.9438
# Val Loss: 0.1825, Val Acc: 0.9454
# Epoch 9
# Train Loss: 0.1843, Train Acc: 0.9440
# Val Loss: 0.1768, Val Acc: 0.9466
# Epoch 10
# Train Loss: 0.1818, Train Acc: 0.9436
# Val Loss: 0.1782, Val Acc: 0.9450
# Fold 3
# Epoch 1
# Train Loss: 0.1797, Train Acc: 0.9449
# Val Loss: 0.1775, Val Acc: 0.9454
# Epoch 2
# Train Loss: 0.1744, Train Acc: 0.9470
# Val Loss: 0.1715, Val Acc: 0.9457
# Epoch 3
# Train Loss: 0.1747, Train Acc: 0.9454
# Val Loss: 0.1654, Val Acc: 0.9501
# Epoch 4
# Train Loss: 0.1720, Train Acc: 0.9474
# Val Loss: 0.1666, Val Acc: 0.9476
# Epoch 5
# Train Loss: 0.1695, Train Acc: 0.9480
# Val Loss: 0.1710, Val Acc: 0.9478
# Epoch 6
# Train Loss: 0.1689, Train Acc: 0.9484
# Val Loss: 0.1628, Val Acc: 0.9486
# Epoch 7
# Train Loss: 0.1641, Train Acc: 0.9496
# Val Loss: 0.1625, Val Acc: 0.9477
# Epoch 8
# Train Loss: 0.1639, Train Acc: 0.9488
# Val Loss: 0.1599, Val Acc: 0.9513
# Epoch 9
# Train Loss: 0.1639, Train Acc: 0.9482
# Val Loss: 0.1600, Val Acc: 0.9512
# Epoch 10
# Train Loss: 0.1616, Train Acc: 0.9501
# Val Loss: 0.1580, Val Acc: 0.9525
# Fold 4
# Epoch 1
# Train Loss: 0.1587, Train Acc: 0.9509
# Val Loss: 0.1631, Val Acc: 0.9493
# Epoch 2
# Train Loss: 0.1572, Train Acc: 0.9507
# Val Loss: 0.1517, Val Acc: 0.9527
# Epoch 3
# Train Loss: 0.1567, Train Acc: 0.9517
# Val Loss: 0.1534, Val Acc: 0.9526
# Epoch 4
# Train Loss: 0.1574, Train Acc: 0.9516
# Val Loss: 0.1558, Val Acc: 0.9516
# Epoch 5
# Train Loss: 0.1568, Train Acc: 0.9521
# Val Loss: 0.1563, Val Acc: 0.9517
# Epoch 6
# Train Loss: 0.1528, Train Acc: 0.9526
# Val Loss: 0.1523, Val Acc: 0.9531
# Epoch 7
# Train Loss: 0.1519, Train Acc: 0.9528
# Val Loss: 0.1539, Val Acc: 0.9505
# Epoch 8
# Train Loss: 0.1500, Train Acc: 0.9536
# Val Loss: 0.1443, Val Acc: 0.9547
# Epoch 9
# Train Loss: 0.1495, Train Acc: 0.9535
# Val Loss: 0.1499, Val Acc: 0.9541
# Epoch 10
# Train Loss: 0.1489, Train Acc: 0.9543
# Val Loss: 0.1426, Val Acc: 0.9540
# Fold 5
# Epoch 1
# Train Loss: 0.1483, Train Acc: 0.9535
# Val Loss: 0.1500, Val Acc: 0.9546
# Epoch 2
# Train Loss: 0.1480, Train Acc: 0.9539
# Val Loss: 0.1484, Val Acc: 0.9537
# Epoch 3
# Train Loss: 0.1442, Train Acc: 0.9555
# Val Loss: 0.1497, Val Acc: 0.9549
# Epoch 4
# Train Loss: 0.1444, Train Acc: 0.9555
# Val Loss: 0.1450, Val Acc: 0.9540
# Epoch 5
# Train Loss: 0.1443, Train Acc: 0.9548
# Val Loss: 0.1474, Val Acc: 0.9545
# Epoch 6
# Train Loss: 0.1421, Train Acc: 0.9562
# Val Loss: 0.1471, Val Acc: 0.9550
# Epoch 7
# Train Loss: 0.1422, Train Acc: 0.9555
# Val Loss: 0.1447, Val Acc: 0.9546
# Epoch 8
# Train Loss: 0.1417, Train Acc: 0.9558
# Val Loss: 0.1448, Val Acc: 0.9563
# Epoch 9
# Train Loss: 0.1368, Train Acc: 0.9573
# Val Loss: 0.1398, Val Acc: 0.9559
# Epoch 10
# [I 2025-02-16 22:55:01,320] Trial 3 finished with value: 0.09416899999999999 and parameters: {'fc1_size': 192, 'fc2_size': 80, 'optimizer': 'Adagrad', 'lr': 0.0015592438075570222, 'batch_size': 128}. Best is trial 3 with value: 0.09416899999999999.
# Train Loss: 0.1396, Train Acc: 0.9558
# Val Loss: 0.1461, Val Acc: 0.9547
# Average Train Loss: 1.1344, Average Train Acc: 0.6356
# Average Val Loss: 1.1241, Average Val Acc: 0.6399
# Fold 1
# Epoch 1
# Train Loss: 2.3136, Train Acc: 0.1240
# Val Loss: 2.3134, Val Acc: 0.1206
# Epoch 2
# Train Loss: 2.3135, Train Acc: 0.1248
# Val Loss: 2.3112, Val Acc: 0.1233
# Epoch 3
# Train Loss: 2.3129, Train Acc: 0.1267
# Val Loss: 2.3122, Val Acc: 0.1271
# Epoch 4
# Train Loss: 2.3124, Train Acc: 0.1255
# Val Loss: 2.3119, Val Acc: 0.1254
# Epoch 5
# Train Loss: 2.3118, Train Acc: 0.1263
# Val Loss: 2.3113, Val Acc: 0.1256
# Epoch 6
# Train Loss: 2.3114, Train Acc: 0.1271
# Val Loss: 2.3107, Val Acc: 0.1262
# Epoch 7
# Train Loss: 2.3105, Train Acc: 0.1262
# Val Loss: 2.3097, Val Acc: 0.1286
# Epoch 8
# Train Loss: 2.3095, Train Acc: 0.1275
# Val Loss: 2.3098, Val Acc: 0.1238
# Epoch 9
# Train Loss: 2.3097, Train Acc: 0.1290
# Val Loss: 2.3084, Val Acc: 0.1284
# Epoch 10
# Train Loss: 2.3095, Train Acc: 0.1296
# Val Loss: 2.3093, Val Acc: 0.1255
# Fold 2
# Epoch 1
# Train Loss: 2.3091, Train Acc: 0.1268
# Val Loss: 2.3076, Val Acc: 0.1277
# Epoch 2
# Train Loss: 2.3083, Train Acc: 0.1274
# Val Loss: 2.3085, Val Acc: 0.1270
# Epoch 3
# Train Loss: 2.3079, Train Acc: 0.1287
# Val Loss: 2.3077, Val Acc: 0.1274
# Epoch 4
# Train Loss: 2.3082, Train Acc: 0.1281
# Val Loss: 2.3067, Val Acc: 0.1282
# Epoch 5
# Train Loss: 2.3079, Train Acc: 0.1268
# Val Loss: 2.3068, Val Acc: 0.1308
# Epoch 6
# Train Loss: 2.3066, Train Acc: 0.1302
# Val Loss: 2.3052, Val Acc: 0.1329
# Epoch 7
# Train Loss: 2.3068, Train Acc: 0.1287
# Val Loss: 2.3053, Val Acc: 0.1293
# Epoch 8
# Train Loss: 2.3059, Train Acc: 0.1307
# Val Loss: 2.3063, Val Acc: 0.1335
# Epoch 9
# Train Loss: 2.3064, Train Acc: 0.1263
# Val Loss: 2.3051, Val Acc: 0.1308
# Epoch 10
# Train Loss: 2.3058, Train Acc: 0.1298
# Val Loss: 2.3045, Val Acc: 0.1288
# Fold 3
# Epoch 1
# Train Loss: 2.3045, Train Acc: 0.1311
# Val Loss: 2.3047, Val Acc: 0.1255
# Epoch 2
# Train Loss: 2.3039, Train Acc: 0.1338
# Val Loss: 2.3048, Val Acc: 0.1278
# Epoch 3
# Train Loss: 2.3042, Train Acc: 0.1323
# Val Loss: 2.3028, Val Acc: 0.1300
# Epoch 4
# Train Loss: 2.3038, Train Acc: 0.1322
# Val Loss: 2.3021, Val Acc: 0.1303
# Epoch 5
# Train Loss: 2.3029, Train Acc: 0.1319
# Val Loss: 2.3019, Val Acc: 0.1327
# Epoch 6
# Train Loss: 2.3026, Train Acc: 0.1333
# Val Loss: 2.3006, Val Acc: 0.1348
# Epoch 7
# Train Loss: 2.3022, Train Acc: 0.1334
# Val Loss: 2.3020, Val Acc: 0.1301
# Epoch 8
# Train Loss: 2.3020, Train Acc: 0.1331
# Val Loss: 2.2999, Val Acc: 0.1311
# Epoch 9
# Train Loss: 2.3014, Train Acc: 0.1332
# Val Loss: 2.2995, Val Acc: 0.1343
# Epoch 10
# Train Loss: 2.3013, Train Acc: 0.1344
# Val Loss: 2.2998, Val Acc: 0.1354
# Fold 4
# Epoch 1
# Train Loss: 2.3002, Train Acc: 0.1343
# Val Loss: 2.3013, Val Acc: 0.1372
# Epoch 2
# Train Loss: 2.2997, Train Acc: 0.1350
# Val Loss: 2.3020, Val Acc: 0.1359
# Epoch 3
# Train Loss: 2.2995, Train Acc: 0.1356
# Val Loss: 2.3008, Val Acc: 0.1376
# Epoch 4
# Train Loss: 2.2998, Train Acc: 0.1319
# Val Loss: 2.3021, Val Acc: 0.1370
# Epoch 5
# Train Loss: 2.2989, Train Acc: 0.1357
# Val Loss: 2.3009, Val Acc: 0.1380
# Epoch 6
# Train Loss: 2.2979, Train Acc: 0.1361
# Val Loss: 2.2985, Val Acc: 0.1366
# Epoch 7
# Train Loss: 2.2971, Train Acc: 0.1363
# Val Loss: 2.2990, Val Acc: 0.1394
# Epoch 8
# Train Loss: 2.2973, Train Acc: 0.1343
# Val Loss: 2.2996, Val Acc: 0.1375
# Epoch 9
# Train Loss: 2.2968, Train Acc: 0.1349
# Val Loss: 2.2985, Val Acc: 0.1393
# Epoch 10
# Train Loss: 2.2963, Train Acc: 0.1368
# Val Loss: 2.2987, Val Acc: 0.1377
# Fold 5
# Epoch 1
# Train Loss: 2.2968, Train Acc: 0.1377
# Val Loss: 2.2977, Val Acc: 0.1348
# Epoch 2
# Train Loss: 2.2958, Train Acc: 0.1369
# Val Loss: 2.2968, Val Acc: 0.1335
# Epoch 3
# Train Loss: 2.2959, Train Acc: 0.1377
# Val Loss: 2.2957, Val Acc: 0.1393
# Epoch 4
# Train Loss: 2.2952, Train Acc: 0.1363
# Val Loss: 2.2962, Val Acc: 0.1383
# Epoch 5
# Train Loss: 2.2947, Train Acc: 0.1396
# Val Loss: 2.2955, Val Acc: 0.1346
# Epoch 6
# Train Loss: 2.2942, Train Acc: 0.1398
# Val Loss: 2.2932, Val Acc: 0.1468
# Epoch 7
# Train Loss: 2.2940, Train Acc: 0.1392
# Val Loss: 2.2935, Val Acc: 0.1404
# Epoch 8
# Train Loss: 2.2938, Train Acc: 0.1376
# Val Loss: 2.2928, Val Acc: 0.1462
# Epoch 9
# Train Loss: 2.2931, Train Acc: 0.1393
# Val Loss: 2.2924, Val Acc: 0.1417
# Epoch 10
# [I 2025-02-16 23:03:43,967] Trial 4 finished with value: 0.0132635 and parameters: {'fc1_size': 64, 'fc2_size': 64, 'optimizer': 'SGD', 'lr': 1.0916582419398939e-05, 'batch_size': 160}. Best is trial 3 with value: 0.09416899999999999.
# Train Loss: 2.2922, Train Acc: 0.1415
# Val Loss: 2.2932, Val Acc: 0.1372
# Average Train Loss: 1.3681, Average Train Acc: 0.5349
# Average Val Loss: 1.3598, Average Val Acc: 0.5385
# Fold 1
# Epoch 1
# Train Loss: 2.3136, Train Acc: 0.0902
# Val Loss: 2.3124, Val Acc: 0.0922
# Epoch 2
# Train Loss: 2.3104, Train Acc: 0.0926
# Val Loss: 2.3087, Val Acc: 0.0965
# Epoch 3
# Train Loss: 2.3064, Train Acc: 0.1007
# Val Loss: 2.3049, Val Acc: 0.1020
# Epoch 4
# Train Loss: 2.3024, Train Acc: 0.1066
# Val Loss: 2.3031, Val Acc: 0.1027
# Epoch 5
# Train Loss: 2.2990, Train Acc: 0.1141
# Val Loss: 2.2977, Val Acc: 0.1154
# Epoch 6
# Train Loss: 2.2957, Train Acc: 0.1176
# Val Loss: 2.2943, Val Acc: 0.1211
# Epoch 7
# Train Loss: 2.2920, Train Acc: 0.1290
# Val Loss: 2.2915, Val Acc: 0.1248
# Epoch 8
# Train Loss: 2.2885, Train Acc: 0.1321
# Val Loss: 2.2863, Val Acc: 0.1363
# Epoch 9
# Train Loss: 2.2857, Train Acc: 0.1397
# Val Loss: 2.2849, Val Acc: 0.1402
# Epoch 10
# Train Loss: 2.2820, Train Acc: 0.1433
# Val Loss: 2.2811, Val Acc: 0.1466
# Fold 2
# Epoch 1
# Train Loss: 2.2784, Train Acc: 0.1504
# Val Loss: 2.2768, Val Acc: 0.1526
# Epoch 2
# Train Loss: 2.2746, Train Acc: 0.1551
# Val Loss: 2.2739, Val Acc: 0.1583
# Epoch 3
# Train Loss: 2.2716, Train Acc: 0.1608
# Val Loss: 2.2715, Val Acc: 0.1609
# Epoch 4
# Train Loss: 2.2676, Train Acc: 0.1660
# Val Loss: 2.2676, Val Acc: 0.1648
# Epoch 5
# Train Loss: 2.2646, Train Acc: 0.1696
# Val Loss: 2.2650, Val Acc: 0.1701
# Epoch 6
# Train Loss: 2.2607, Train Acc: 0.1748
# Val Loss: 2.2606, Val Acc: 0.1734
# Epoch 7
# Train Loss: 2.2575, Train Acc: 0.1765
# Val Loss: 2.2560, Val Acc: 0.1799
# Epoch 8
# Train Loss: 2.2537, Train Acc: 0.1809
# Val Loss: 2.2543, Val Acc: 0.1747
# Epoch 9
# Train Loss: 2.2497, Train Acc: 0.1868
# Val Loss: 2.2482, Val Acc: 0.1873
# Epoch 10
# Train Loss: 2.2461, Train Acc: 0.1877
# Val Loss: 2.2442, Val Acc: 0.1897
# Fold 3
# Epoch 1
# Train Loss: 2.2436, Train Acc: 0.1909
# Val Loss: 2.2391, Val Acc: 0.1938
# Epoch 2
# Train Loss: 2.2399, Train Acc: 0.1919
# Val Loss: 2.2356, Val Acc: 0.1938
# Epoch 3
# Train Loss: 2.2360, Train Acc: 0.1974
# Val Loss: 2.2325, Val Acc: 0.2003
# Epoch 4
# Train Loss: 2.2315, Train Acc: 0.2017
# Val Loss: 2.2284, Val Acc: 0.2018
# Epoch 5
# Train Loss: 2.2274, Train Acc: 0.2027
# Val Loss: 2.2235, Val Acc: 0.2106
# Epoch 6
# Train Loss: 2.2241, Train Acc: 0.2075
# Val Loss: 2.2204, Val Acc: 0.2107
# Epoch 7
# Train Loss: 2.2192, Train Acc: 0.2131
# Val Loss: 2.2163, Val Acc: 0.2164
# Epoch 8
# Train Loss: 2.2147, Train Acc: 0.2170
# Val Loss: 2.2110, Val Acc: 0.2213
# Epoch 9
# Train Loss: 2.2100, Train Acc: 0.2210
# Val Loss: 2.2080, Val Acc: 0.2259
# Epoch 10
# Train Loss: 2.2061, Train Acc: 0.2268
# Val Loss: 2.2027, Val Acc: 0.2323
# Fold 4
# Epoch 1
# Train Loss: 2.2011, Train Acc: 0.2312
# Val Loss: 2.2004, Val Acc: 0.2332
# Epoch 2
# Train Loss: 2.1959, Train Acc: 0.2384
# Val Loss: 2.1982, Val Acc: 0.2349
# Epoch 3
# Train Loss: 2.1912, Train Acc: 0.2432
# Val Loss: 2.1907, Val Acc: 0.2452
# Epoch 4
# Train Loss: 2.1867, Train Acc: 0.2516
# Val Loss: 2.1873, Val Acc: 0.2448
# Epoch 5
# Train Loss: 2.1816, Train Acc: 0.2571
# Val Loss: 2.1807, Val Acc: 0.2567
# Epoch 6
# Train Loss: 2.1765, Train Acc: 0.2636
# Val Loss: 2.1754, Val Acc: 0.2652
# Epoch 7
# Train Loss: 2.1703, Train Acc: 0.2711
# Val Loss: 2.1694, Val Acc: 0.2718
# Epoch 8
# Train Loss: 2.1660, Train Acc: 0.2743
# Val Loss: 2.1656, Val Acc: 0.2792
# Epoch 9
# Train Loss: 2.1599, Train Acc: 0.2832
# Val Loss: 2.1604, Val Acc: 0.2858
# Epoch 10
# Train Loss: 2.1543, Train Acc: 0.2916
# Val Loss: 2.1542, Val Acc: 0.2885
# Fold 5
# Epoch 1
# Train Loss: 2.1501, Train Acc: 0.2938
# Val Loss: 2.1442, Val Acc: 0.3031
# Epoch 2
# Train Loss: 2.1443, Train Acc: 0.3030
# Val Loss: 2.1390, Val Acc: 0.3013
# Epoch 3
# Train Loss: 2.1374, Train Acc: 0.3052
# Val Loss: 2.1304, Val Acc: 0.3161
# Epoch 4
# Train Loss: 2.1317, Train Acc: 0.3123
# Val Loss: 2.1250, Val Acc: 0.3147
# Epoch 5
# Train Loss: 2.1251, Train Acc: 0.3185
# Val Loss: 2.1186, Val Acc: 0.3249
# Epoch 6
# Train Loss: 2.1189, Train Acc: 0.3226
# Val Loss: 2.1115, Val Acc: 0.3369
# Epoch 7
# Train Loss: 2.1114, Train Acc: 0.3292
# Val Loss: 2.1045, Val Acc: 0.3354
# Epoch 8
# Train Loss: 2.1057, Train Acc: 0.3333
# Val Loss: 2.0987, Val Acc: 0.3412
# Epoch 9
# Train Loss: 2.0986, Train Acc: 0.3392
# Val Loss: 2.0939, Val Acc: 0.3418
# Epoch 10
# [I 2025-02-16 23:12:24,522] Trial 5 finished with value: 0.021729000000000005 and parameters: {'fc1_size': 192, 'fc2_size': 64, 'optimizer': 'SGD', 'lr': 5.925572571921635e-05, 'batch_size': 160}. Best is trial 3 with value: 0.09416899999999999.
# Train Loss: 2.0926, Train Acc: 0.3434
# Val Loss: 2.0860, Val Acc: 0.3473
# Average Train Loss: 1.5096, Average Train Acc: 0.4816
# Average Val Loss: 1.5023, Average Val Acc: 0.4849
# Fold 1
# Epoch 1
# Train Loss: 2.1700, Train Acc: 0.2064
# Val Loss: 1.9787, Val Acc: 0.2106
# Epoch 2
# Train Loss: 1.3425, Train Acc: 0.5064
# Val Loss: 0.9172, Val Acc: 0.6633
# Epoch 3
# Train Loss: 0.7585, Train Acc: 0.7512
# Val Loss: 0.6404, Val Acc: 0.7934
# Epoch 4
# Train Loss: 0.6004, Train Acc: 0.8061
# Val Loss: 0.5783, Val Acc: 0.8078
# Epoch 5
# Train Loss: 0.7329, Train Acc: 0.7846
# Val Loss: 0.5967, Val Acc: 0.8137
# Epoch 6
# Train Loss: 0.6880, Train Acc: 0.8067
# Val Loss: 0.6643, Val Acc: 0.8132
# Epoch 7
# Train Loss: 0.5930, Train Acc: 0.8328
# Val Loss: 0.6376, Val Acc: 0.8123
# Epoch 8
# Train Loss: 0.6227, Train Acc: 0.8333
# Val Loss: 0.7212, Val Acc: 0.8110
# Epoch 9
# Train Loss: 0.6347, Train Acc: 0.8269
# Val Loss: 0.6216, Val Acc: 0.8096
# Epoch 10
# Train Loss: 0.7816, Train Acc: 0.7886
# Val Loss: 1.0029, Val Acc: 0.7718
# Fold 2
# Epoch 1
# Train Loss: 0.7708, Train Acc: 0.7876
# Val Loss: 0.6159, Val Acc: 0.8287
# Epoch 2
# Train Loss: 0.6218, Train Acc: 0.8314
# Val Loss: 0.6030, Val Acc: 0.8279
# Epoch 3
# Train Loss: 0.6200, Train Acc: 0.8389
# Val Loss: 0.6073, Val Acc: 0.8532
# Epoch 4
# Train Loss: 0.5688, Train Acc: 0.8481
# Val Loss: 0.5994, Val Acc: 0.8494
# Epoch 5
# Train Loss: 0.6850, Train Acc: 0.8285
# Val Loss: 0.5744, Val Acc: 0.8571
# Epoch 6
# Train Loss: 0.5523, Train Acc: 0.8585
# Val Loss: 0.5473, Val Acc: 0.8496
# Epoch 7
# Train Loss: 0.5180, Train Acc: 0.8665
# Val Loss: 0.4975, Val Acc: 0.8872
# Epoch 8
# Train Loss: 0.5272, Train Acc: 0.8674
# Val Loss: 0.6141, Val Acc: 0.8444
# Epoch 9
# Train Loss: 1.3895, Train Acc: 0.5831
# Val Loss: 2.3058, Val Acc: 0.1143
# Epoch 10
# Train Loss: 2.3062, Train Acc: 0.1049
# Val Loss: 2.3039, Val Acc: 0.0993
# Fold 3
# Epoch 1
# Train Loss: 2.3059, Train Acc: 0.1056
# Val Loss: 2.3050, Val Acc: 0.0957
# Epoch 2
# Train Loss: 2.3052, Train Acc: 0.1045
# Val Loss: 2.3078, Val Acc: 0.0976
# Epoch 3
# Train Loss: 2.3051, Train Acc: 0.1044
# Val Loss: 2.3032, Val Acc: 0.0963
# Epoch 4
# Train Loss: 2.3329, Train Acc: 0.1040
# Val Loss: 2.3049, Val Acc: 0.1128
# Epoch 5
# Train Loss: 2.3050, Train Acc: 0.1064
# Val Loss: 2.3020, Val Acc: 0.1128
# Epoch 6
# Train Loss: 2.3052, Train Acc: 0.1061
# Val Loss: 2.3047, Val Acc: 0.1128
# Epoch 7
# Train Loss: 2.3055, Train Acc: 0.1058
# Val Loss: 2.3062, Val Acc: 0.1010
# Epoch 8
# Train Loss: 2.3053, Train Acc: 0.1073
# Val Loss: 2.3036, Val Acc: 0.1010
# Epoch 9
# Train Loss: 2.3053, Train Acc: 0.1062
# Val Loss: 2.3032, Val Acc: 0.1050
# Epoch 10
# Train Loss: 2.3046, Train Acc: 0.1081
# Val Loss: 2.3062, Val Acc: 0.0976
# Fold 4
# Epoch 1
# Train Loss: 2.3053, Train Acc: 0.1042
# Val Loss: 2.3090, Val Acc: 0.0966
# Epoch 2
# Train Loss: 2.3050, Train Acc: 0.1064
# Val Loss: 2.3076, Val Acc: 0.0993
# Epoch 3
# Train Loss: 2.3053, Train Acc: 0.1057
# Val Loss: 2.3085, Val Acc: 0.0993
# Epoch 4
# Train Loss: 2.3051, Train Acc: 0.1071
# Val Loss: 2.3042, Val Acc: 0.1121
# Epoch 5
# Train Loss: 2.3059, Train Acc: 0.1054
# Val Loss: 2.3052, Val Acc: 0.1121
# Epoch 6
# Train Loss: 2.3052, Train Acc: 0.1047
# Val Loss: 2.3035, Val Acc: 0.1121
# Epoch 7
# Train Loss: 2.3048, Train Acc: 0.1069
# Val Loss: 2.3027, Val Acc: 0.1121
# Epoch 8
# Train Loss: 2.3052, Train Acc: 0.1055
# Val Loss: 2.3027, Val Acc: 0.1007
# Epoch 9
# Train Loss: 2.3052, Train Acc: 0.1034
# Val Loss: 2.3061, Val Acc: 0.1121
# Epoch 10
# Train Loss: 2.3047, Train Acc: 0.1086
# Val Loss: 2.3029, Val Acc: 0.1027
# Fold 5
# Epoch 1
# Train Loss: 2.3049, Train Acc: 0.1054
# Val Loss: 2.3080, Val Acc: 0.0990
# Epoch 2
# Train Loss: 2.3047, Train Acc: 0.1058
# Val Loss: 2.3023, Val Acc: 0.1057
# Epoch 3
# Train Loss: 2.3048, Train Acc: 0.1052
# Val Loss: 2.3018, Val Acc: 0.1050
# Epoch 4
# Train Loss: 2.3051, Train Acc: 0.1045
# Val Loss: 2.3033, Val Acc: 0.1057
# Epoch 5
# Train Loss: 2.3047, Train Acc: 0.1051
# Val Loss: 2.3059, Val Acc: 0.0990
# Epoch 6
# Train Loss: 2.3048, Train Acc: 0.1040
# Val Loss: 2.3051, Val Acc: 0.1107
# Epoch 7
# Train Loss: 2.3045, Train Acc: 0.1070
# Val Loss: 2.3101, Val Acc: 0.0990
# Epoch 8
# Train Loss: 2.3045, Train Acc: 0.1061
# Val Loss: 2.3043, Val Acc: 0.1107
# Epoch 9
# Train Loss: 2.3049, Train Acc: 0.1077
# Val Loss: 2.3063, Val Acc: 0.1107
# Epoch 10
# [I 2025-02-16 23:21:05,602] Trial 6 finished with value: 0.03490733333333334 and parameters: {'fc1_size': 96, 'fc2_size': 64, 'optimizer': 'Adam', 'lr': 0.06654869291065385, 'batch_size': 160}. Best is trial 3 with value: 0.09416899999999999.
# Train Loss: 2.3047, Train Acc: 0.1067
# Val Loss: 2.3080, Val Acc: 0.0990
# Average Train Loss: 1.5415, Average Train Acc: 0.4635
# Average Val Loss: 1.5356, Average Val Acc: 0.4655
# Fold 1
# Epoch 1
# Train Loss: 2.1416, Train Acc: 0.3606
# Val Loss: 1.9911, Val Acc: 0.5251
# Epoch 2
# Train Loss: 1.8256, Train Acc: 0.5723
# Val Loss: 1.6645, Val Acc: 0.6055
# Epoch 3
# Train Loss: 1.5021, Train Acc: 0.6409
# Val Loss: 1.3704, Val Acc: 0.6593
# Epoch 4
# Train Loss: 1.2395, Train Acc: 0.6837
# Val Loss: 1.1456, Val Acc: 0.6978
# Epoch 5
# Train Loss: 1.0473, Train Acc: 0.7152
# Val Loss: 0.9869, Val Acc: 0.7197
# Epoch 6
# Train Loss: 0.9161, Train Acc: 0.7404
# Val Loss: 0.8674, Val Acc: 0.7522
# Epoch 7
# Train Loss: 0.8196, Train Acc: 0.7599
# Val Loss: 0.7922, Val Acc: 0.7638
# Epoch 8
# Train Loss: 0.7476, Train Acc: 0.7774
# Val Loss: 0.7175, Val Acc: 0.7841
# Epoch 9
# Train Loss: 0.6918, Train Acc: 0.7922
# Val Loss: 0.6750, Val Acc: 0.7978
# Epoch 10
# Train Loss: 0.6454, Train Acc: 0.8025
# Val Loss: 0.6399, Val Acc: 0.8061
# Fold 2
# Epoch 1
# Train Loss: 0.6112, Train Acc: 0.8128
# Val Loss: 0.5889, Val Acc: 0.8171
# Epoch 2
# Train Loss: 0.5790, Train Acc: 0.8236
# Val Loss: 0.5517, Val Acc: 0.8301
# Epoch 3
# Train Loss: 0.5522, Train Acc: 0.8325
# Val Loss: 0.5284, Val Acc: 0.8376
# Epoch 4
# Train Loss: 0.5307, Train Acc: 0.8366
# Val Loss: 0.5136, Val Acc: 0.8438
# Epoch 5
# Train Loss: 0.5110, Train Acc: 0.8427
# Val Loss: 0.4965, Val Acc: 0.8449
# Epoch 6
# Train Loss: 0.4876, Train Acc: 0.8487
# Val Loss: 0.4738, Val Acc: 0.8561
# Epoch 7
# Train Loss: 0.4695, Train Acc: 0.8539
# Val Loss: 0.4529, Val Acc: 0.8608
# Epoch 8
# Train Loss: 0.4569, Train Acc: 0.8580
# Val Loss: 0.4460, Val Acc: 0.8599
# Epoch 9
# Train Loss: 0.4447, Train Acc: 0.8618
# Val Loss: 0.4313, Val Acc: 0.8652
# Epoch 10
# Train Loss: 0.4316, Train Acc: 0.8661
# Val Loss: 0.4172, Val Acc: 0.8710
# Fold 3
# Epoch 1
# Train Loss: 0.4153, Train Acc: 0.8712
# Val Loss: 0.4155, Val Acc: 0.8707
# Epoch 2
# Train Loss: 0.4085, Train Acc: 0.8739
# Val Loss: 0.3981, Val Acc: 0.8758
# Epoch 3
# Train Loss: 0.3990, Train Acc: 0.8757
# Val Loss: 0.3939, Val Acc: 0.8758
# Epoch 4
# Train Loss: 0.3889, Train Acc: 0.8782
# Val Loss: 0.3854, Val Acc: 0.8779
# Epoch 5
# Train Loss: 0.3732, Train Acc: 0.8851
# Val Loss: 0.3771, Val Acc: 0.8823
# Epoch 6
# Train Loss: 0.3674, Train Acc: 0.8848
# Val Loss: 0.3636, Val Acc: 0.8838
# Epoch 7
# Train Loss: 0.3607, Train Acc: 0.8878
# Val Loss: 0.3551, Val Acc: 0.8878
# Epoch 8
# Train Loss: 0.3516, Train Acc: 0.8904
# Val Loss: 0.3444, Val Acc: 0.8956
# Epoch 9
# Train Loss: 0.3443, Train Acc: 0.8918
# Val Loss: 0.3417, Val Acc: 0.8939
# Epoch 10
# Train Loss: 0.3423, Train Acc: 0.8936
# Val Loss: 0.3332, Val Acc: 0.8970
# Fold 4
# Epoch 1
# Train Loss: 0.3361, Train Acc: 0.8946
# Val Loss: 0.3273, Val Acc: 0.8988
# Epoch 2
# Train Loss: 0.3275, Train Acc: 0.8976
# Val Loss: 0.3230, Val Acc: 0.8990
# Epoch 3
# Train Loss: 0.3201, Train Acc: 0.8985
# Val Loss: 0.3191, Val Acc: 0.8996
# Epoch 4
# Train Loss: 0.3152, Train Acc: 0.9000
# Val Loss: 0.3112, Val Acc: 0.9042
# Epoch 5
# Train Loss: 0.3104, Train Acc: 0.9029
# Val Loss: 0.3012, Val Acc: 0.9080
# Epoch 6
# Train Loss: 0.3041, Train Acc: 0.9056
# Val Loss: 0.2972, Val Acc: 0.9093
# Epoch 7
# Train Loss: 0.3001, Train Acc: 0.9067
# Val Loss: 0.2937, Val Acc: 0.9087
# Epoch 8
# Train Loss: 0.2927, Train Acc: 0.9087
# Val Loss: 0.2928, Val Acc: 0.9064
# Epoch 9
# Train Loss: 0.2900, Train Acc: 0.9098
# Val Loss: 0.2900, Val Acc: 0.9107
# Epoch 10
# Train Loss: 0.2856, Train Acc: 0.9108
# Val Loss: 0.2835, Val Acc: 0.9128
# Fold 5
# Epoch 1
# Train Loss: 0.2771, Train Acc: 0.9146
# Val Loss: 0.2770, Val Acc: 0.9136
# Epoch 2
# Train Loss: 0.2765, Train Acc: 0.9160
# Val Loss: 0.2706, Val Acc: 0.9125
# Epoch 3
# Train Loss: 0.2702, Train Acc: 0.9173
# Val Loss: 0.2672, Val Acc: 0.9173
# Epoch 4
# Train Loss: 0.2688, Train Acc: 0.9161
# Val Loss: 0.2684, Val Acc: 0.9187
# Epoch 5
# Train Loss: 0.2636, Train Acc: 0.9185
# Val Loss: 0.2596, Val Acc: 0.9178
# Epoch 6
# Train Loss: 0.2580, Train Acc: 0.9195
# Val Loss: 0.2560, Val Acc: 0.9188
# Epoch 7
# Train Loss: 0.2602, Train Acc: 0.9204
# Val Loss: 0.2634, Val Acc: 0.9187
# Epoch 8
# Train Loss: 0.2544, Train Acc: 0.9214
# Val Loss: 0.2575, Val Acc: 0.9190
# Epoch 9
# Train Loss: 0.2490, Train Acc: 0.9234
# Val Loss: 0.2486, Val Acc: 0.9217
# Epoch 10
# [I 2025-02-16 23:29:34,919] Trial 7 finished with value: 0.08534850000000001 and parameters: {'fc1_size': 192, 'fc2_size': 96, 'optimizer': 'RMSprop', 'lr': 1.2727473480800384e-05, 'batch_size': 256}. Best is trial 3 with value: 0.09416899999999999.
# Train Loss: 0.2465, Train Acc: 0.9231
# Val Loss: 0.2497, Val Acc: 0.9200
# Average Train Loss: 1.4141, Average Train Acc: 0.5114
# Average Val Loss: 1.4065, Average Val Acc: 0.5140
# Fold 1
# Epoch 1
# Train Loss: 0.8929, Train Acc: 0.7343
# Val Loss: 0.4237, Val Acc: 0.8639
# Epoch 2
# Train Loss: 0.3342, Train Acc: 0.8962
# Val Loss: 0.2750, Val Acc: 0.9137
# Epoch 3
# Train Loss: 0.2359, Train Acc: 0.9266
# Val Loss: 0.2157, Val Acc: 0.9337
# Epoch 4
# Train Loss: 0.1928, Train Acc: 0.9399
# Val Loss: 0.1945, Val Acc: 0.9397
# Epoch 5
# Train Loss: 0.1724, Train Acc: 0.9454
# Val Loss: 0.1728, Val Acc: 0.9483
# Epoch 6
# Train Loss: 0.1542, Train Acc: 0.9514
# Val Loss: 0.1524, Val Acc: 0.9522
# Epoch 7
# Train Loss: 0.1421, Train Acc: 0.9557
# Val Loss: 0.1435, Val Acc: 0.9552
# Epoch 8
# Train Loss: 0.1355, Train Acc: 0.9572
# Val Loss: 0.1474, Val Acc: 0.9534
# Epoch 9
# Train Loss: 0.1279, Train Acc: 0.9593
# Val Loss: 0.1409, Val Acc: 0.9548
# Epoch 10
# Train Loss: 0.1194, Train Acc: 0.9630
# Val Loss: 0.1247, Val Acc: 0.9616
# Fold 2
# Epoch 1
# Train Loss: 0.1181, Train Acc: 0.9632
# Val Loss: 0.1051, Val Acc: 0.9654
# Epoch 2
# Train Loss: 0.1160, Train Acc: 0.9628
# Val Loss: 0.1142, Val Acc: 0.9633
# Epoch 3
# Train Loss: 0.1107, Train Acc: 0.9649
# Val Loss: 0.1045, Val Acc: 0.9651
# Epoch 4
# Train Loss: 0.1045, Train Acc: 0.9674
# Val Loss: 0.0933, Val Acc: 0.9701
# Epoch 5
# Train Loss: 0.1014, Train Acc: 0.9679
# Val Loss: 0.0970, Val Acc: 0.9684
# Epoch 6
# Train Loss: 0.0970, Train Acc: 0.9692
# Val Loss: 0.0987, Val Acc: 0.9673
# Epoch 7
# Train Loss: 0.0976, Train Acc: 0.9700
# Val Loss: 0.0892, Val Acc: 0.9712
# Epoch 8
# Train Loss: 0.0942, Train Acc: 0.9700
# Val Loss: 0.0858, Val Acc: 0.9718
# Epoch 9
# Train Loss: 0.0913, Train Acc: 0.9708
# Val Loss: 0.0897, Val Acc: 0.9712
# Epoch 10
# Train Loss: 0.0889, Train Acc: 0.9711
# Val Loss: 0.0840, Val Acc: 0.9722
# Fold 3
# Epoch 1
# Train Loss: 0.0862, Train Acc: 0.9718
# Val Loss: 0.0868, Val Acc: 0.9715
# Epoch 2
# Train Loss: 0.0843, Train Acc: 0.9730
# Val Loss: 0.0875, Val Acc: 0.9728
# Epoch 3
# Train Loss: 0.0849, Train Acc: 0.9729
# Val Loss: 0.0884, Val Acc: 0.9732
# Epoch 4
# Train Loss: 0.0803, Train Acc: 0.9739
# Val Loss: 0.0828, Val Acc: 0.9752
# Epoch 5
# Train Loss: 0.0790, Train Acc: 0.9740
# Val Loss: 0.0811, Val Acc: 0.9731
# Epoch 6
# Train Loss: 0.0767, Train Acc: 0.9753
# Val Loss: 0.0867, Val Acc: 0.9738
# Epoch 7
# Train Loss: 0.0756, Train Acc: 0.9763
# Val Loss: 0.0815, Val Acc: 0.9745
# Epoch 8
# Train Loss: 0.0730, Train Acc: 0.9773
# Val Loss: 0.0749, Val Acc: 0.9765
# Epoch 9
# Train Loss: 0.0726, Train Acc: 0.9766
# Val Loss: 0.0796, Val Acc: 0.9762
# Epoch 10
# Train Loss: 0.0714, Train Acc: 0.9766
# Val Loss: 0.0811, Val Acc: 0.9753
# Fold 4
# Epoch 1
# Train Loss: 0.0716, Train Acc: 0.9772
# Val Loss: 0.0713, Val Acc: 0.9776
# Epoch 2
# Train Loss: 0.0693, Train Acc: 0.9775
# Val Loss: 0.0662, Val Acc: 0.9802
# Epoch 3
# Train Loss: 0.0698, Train Acc: 0.9773
# Val Loss: 0.0714, Val Acc: 0.9781
# Epoch 4
# Train Loss: 0.0666, Train Acc: 0.9780
# Val Loss: 0.0683, Val Acc: 0.9774
# Epoch 5
# Train Loss: 0.0649, Train Acc: 0.9787
# Val Loss: 0.0717, Val Acc: 0.9773
# Epoch 6
# Train Loss: 0.0655, Train Acc: 0.9789
# Val Loss: 0.0682, Val Acc: 0.9797
# Epoch 7
# Train Loss: 0.0644, Train Acc: 0.9784
# Val Loss: 0.0685, Val Acc: 0.9773
# Epoch 8
# Train Loss: 0.0628, Train Acc: 0.9798
# Val Loss: 0.0643, Val Acc: 0.9802
# Epoch 9
# Train Loss: 0.0636, Train Acc: 0.9792
# Val Loss: 0.0675, Val Acc: 0.9783
# Epoch 10
# Train Loss: 0.0623, Train Acc: 0.9793
# Val Loss: 0.0730, Val Acc: 0.9760
# Fold 5
# Epoch 1
# Train Loss: 0.0636, Train Acc: 0.9790
# Val Loss: 0.0613, Val Acc: 0.9798
# Epoch 2
# Train Loss: 0.0617, Train Acc: 0.9799
# Val Loss: 0.0581, Val Acc: 0.9813
# Epoch 3
# Train Loss: 0.0635, Train Acc: 0.9795
# Val Loss: 0.0634, Val Acc: 0.9794
# Epoch 4
# Train Loss: 0.0597, Train Acc: 0.9810
# Val Loss: 0.0590, Val Acc: 0.9808
# Epoch 5
# Train Loss: 0.0600, Train Acc: 0.9810
# Val Loss: 0.0579, Val Acc: 0.9808
# Epoch 6
# Train Loss: 0.0585, Train Acc: 0.9808
# Val Loss: 0.0639, Val Acc: 0.9798
# Epoch 7
# Train Loss: 0.0568, Train Acc: 0.9807
# Val Loss: 0.0680, Val Acc: 0.9781
# Epoch 8
# Train Loss: 0.0580, Train Acc: 0.9818
# Val Loss: 0.0732, Val Acc: 0.9771
# Epoch 9
# Train Loss: 0.0564, Train Acc: 0.9814
# Val Loss: 0.0634, Val Acc: 0.9807
# Epoch 10
# [I 2025-02-16 23:38:01,487] Trial 8 finished with value: 0.09676799999999999 and parameters: {'fc1_size': 64, 'fc2_size': 112, 'optimizer': 'Adam', 'lr': 0.0003730978259528612, 'batch_size': 224}. Best is trial 8 with value: 0.09676799999999999.
# Train Loss: 0.0556, Train Acc: 0.9814
# Val Loss: 0.0635, Val Acc: 0.9795
# Average Train Loss: 1.2694, Average Train Acc: 0.5618
# Average Val Loss: 1.2615, Average Val Acc: 0.5644
# Fold 1
# Epoch 1
# Train Loss: 1.3598, Train Acc: 0.6128
# Val Loss: 0.8326, Val Acc: 0.7428
# Epoch 2
# Train Loss: 0.6967, Train Acc: 0.7865
# Val Loss: 0.5905, Val Acc: 0.8163
# Epoch 3
# Train Loss: 0.5231, Train Acc: 0.8364
# Val Loss: 0.4662, Val Acc: 0.8519
# Epoch 4
# Train Loss: 0.4371, Train Acc: 0.8612
# Val Loss: 0.4016, Val Acc: 0.8743
# Epoch 5
# Train Loss: 0.3819, Train Acc: 0.8799
# Val Loss: 0.3538, Val Acc: 0.8834
# Epoch 6
# Train Loss: 0.3430, Train Acc: 0.8886
# Val Loss: 0.3221, Val Acc: 0.8984
# Epoch 7
# Train Loss: 0.3143, Train Acc: 0.8985
# Val Loss: 0.3015, Val Acc: 0.9024
# Epoch 8
# Train Loss: 0.2903, Train Acc: 0.9071
# Val Loss: 0.2811, Val Acc: 0.9111
# Epoch 9
# Train Loss: 0.2763, Train Acc: 0.9108
# Val Loss: 0.2686, Val Acc: 0.9121
# Epoch 10
# Train Loss: 0.2632, Train Acc: 0.9151
# Val Loss: 0.2601, Val Acc: 0.9169
# Fold 2
# Epoch 1
# Train Loss: 0.2500, Train Acc: 0.9195
# Val Loss: 0.2439, Val Acc: 0.9239
# Epoch 2
# Train Loss: 0.2364, Train Acc: 0.9250
# Val Loss: 0.2427, Val Acc: 0.9240
# Epoch 3
# Train Loss: 0.2282, Train Acc: 0.9278
# Val Loss: 0.2267, Val Acc: 0.9288
# Epoch 4
# Train Loss: 0.2146, Train Acc: 0.9317
# Val Loss: 0.2173, Val Acc: 0.9333
# Epoch 5
# Train Loss: 0.2086, Train Acc: 0.9339
# Val Loss: 0.2171, Val Acc: 0.9303
# Epoch 6
# Train Loss: 0.2002, Train Acc: 0.9370
# Val Loss: 0.2023, Val Acc: 0.9368
# Epoch 7
# Train Loss: 0.1925, Train Acc: 0.9384
# Val Loss: 0.2012, Val Acc: 0.9353
# Epoch 8
# Train Loss: 0.1869, Train Acc: 0.9407
# Val Loss: 0.1905, Val Acc: 0.9407
# Epoch 9
# Train Loss: 0.1788, Train Acc: 0.9431
# Val Loss: 0.1886, Val Acc: 0.9401
# Epoch 10
# Train Loss: 0.1758, Train Acc: 0.9439
# Val Loss: 0.1847, Val Acc: 0.9427
# Fold 3
# Epoch 1
# Train Loss: 0.1746, Train Acc: 0.9449
# Val Loss: 0.1678, Val Acc: 0.9457
# Epoch 2
# Train Loss: 0.1705, Train Acc: 0.9464
# Val Loss: 0.1737, Val Acc: 0.9458
# Epoch 3
# Train Loss: 0.1642, Train Acc: 0.9482
# Val Loss: 0.1646, Val Acc: 0.9484
# Epoch 4
# Train Loss: 0.1600, Train Acc: 0.9505
# Val Loss: 0.1588, Val Acc: 0.9485
# Epoch 5
# Train Loss: 0.1567, Train Acc: 0.9510
# Val Loss: 0.1578, Val Acc: 0.9502
# Epoch 6
# Train Loss: 0.1531, Train Acc: 0.9511
# Val Loss: 0.1589, Val Acc: 0.9513
# Epoch 7
# Train Loss: 0.1491, Train Acc: 0.9530
# Val Loss: 0.1549, Val Acc: 0.9509
# Epoch 8
# Train Loss: 0.1487, Train Acc: 0.9533
# Val Loss: 0.1508, Val Acc: 0.9511
# Epoch 9
# Train Loss: 0.1480, Train Acc: 0.9539
# Val Loss: 0.1459, Val Acc: 0.9543
# Epoch 10
# Train Loss: 0.1417, Train Acc: 0.9560
# Val Loss: 0.1444, Val Acc: 0.9545
# Fold 4
# Epoch 1
# Train Loss: 0.1437, Train Acc: 0.9534
# Val Loss: 0.1389, Val Acc: 0.9566
# Epoch 2
# Train Loss: 0.1377, Train Acc: 0.9559
# Val Loss: 0.1470, Val Acc: 0.9540
# Epoch 3
# Train Loss: 0.1361, Train Acc: 0.9568
# Val Loss: 0.1342, Val Acc: 0.9581
# Epoch 4
# Train Loss: 0.1318, Train Acc: 0.9569
# Val Loss: 0.1397, Val Acc: 0.9561
# Epoch 5
# Train Loss: 0.1306, Train Acc: 0.9590
# Val Loss: 0.1368, Val Acc: 0.9583
# Epoch 6
# Train Loss: 0.1274, Train Acc: 0.9594
# Val Loss: 0.1344, Val Acc: 0.9553
# Epoch 7
# Train Loss: 0.1309, Train Acc: 0.9583
# Val Loss: 0.1426, Val Acc: 0.9554
# Epoch 8
# Train Loss: 0.1274, Train Acc: 0.9598
# Val Loss: 0.1283, Val Acc: 0.9582
# Epoch 9
# Train Loss: 0.1233, Train Acc: 0.9611
# Val Loss: 0.1295, Val Acc: 0.9603
# Epoch 10
# Train Loss: 0.1249, Train Acc: 0.9606
# Val Loss: 0.1274, Val Acc: 0.9590
# Fold 5
# Epoch 1
# Train Loss: 0.1240, Train Acc: 0.9604
# Val Loss: 0.1132, Val Acc: 0.9627
# Epoch 2
# Train Loss: 0.1220, Train Acc: 0.9615
# Val Loss: 0.1182, Val Acc: 0.9633
# Epoch 3
# Train Loss: 0.1226, Train Acc: 0.9609
# Val Loss: 0.1118, Val Acc: 0.9633
# Epoch 4
# Train Loss: 0.1189, Train Acc: 0.9619
# Val Loss: 0.1107, Val Acc: 0.9644
# Epoch 5
# Train Loss: 0.1193, Train Acc: 0.9620
# Val Loss: 0.1138, Val Acc: 0.9647
# Epoch 6
# Train Loss: 0.1195, Train Acc: 0.9624
# Val Loss: 0.1042, Val Acc: 0.9684
# Epoch 7
# Train Loss: 0.1171, Train Acc: 0.9632
# Val Loss: 0.1077, Val Acc: 0.9639
# Epoch 8
# Train Loss: 0.1147, Train Acc: 0.9636
# Val Loss: 0.1090, Val Acc: 0.9662
# Epoch 9
# Train Loss: 0.1141, Train Acc: 0.9641
# Val Loss: 0.1035, Val Acc: 0.9668
# Epoch 10
# [I 2025-02-16 23:46:32,876] Trial 9 finished with value: 0.0935385 and parameters: {'fc1_size': 64, 'fc2_size': 112, 'optimizer': 'RMSprop', 'lr': 7.348121202523417e-05, 'batch_size': 160}. Best is trial 8 with value: 0.09676799999999999.
# Train Loss: 0.1112, Train Acc: 0.9646
# Val Loss: 0.1031, Val Acc: 0.9678
# Average Train Loss: 1.1645, Average Train Acc: 0.5987
# Average Val Loss: 1.1558, Average Val Acc: 0.6015
# Fold 1
# Epoch 1
# Train Loss: 0.3081, Train Acc: 0.9001
# Val Loss: 0.1821, Val Acc: 0.9443
# Epoch 2
# Train Loss: 0.1609, Train Acc: 0.9515
# Val Loss: 0.1560, Val Acc: 0.9518
# Epoch 3
# Train Loss: 0.1361, Train Acc: 0.9584
# Val Loss: 0.1434, Val Acc: 0.9589
# Epoch 4
# Train Loss: 0.1185, Train Acc: 0.9636
# Val Loss: 0.1142, Val Acc: 0.9668
# Epoch 5
# Train Loss: 0.1081, Train Acc: 0.9672
# Val Loss: 0.1180, Val Acc: 0.9647
# Epoch 6
# Train Loss: 0.1033, Train Acc: 0.9677
# Val Loss: 0.1131, Val Acc: 0.9678
# Epoch 7
# Train Loss: 0.0978, Train Acc: 0.9701
# Val Loss: 0.1082, Val Acc: 0.9677
# Epoch 8
# Train Loss: 0.0888, Train Acc: 0.9727
# Val Loss: 0.0977, Val Acc: 0.9720
# Epoch 9
# Train Loss: 0.0893, Train Acc: 0.9723
# Val Loss: 0.0976, Val Acc: 0.9710
# Epoch 10
# Train Loss: 0.0864, Train Acc: 0.9731
# Val Loss: 0.0960, Val Acc: 0.9732
# Fold 2
# Epoch 1
# Train Loss: 0.0893, Train Acc: 0.9726
# Val Loss: 0.0764, Val Acc: 0.9758
# Epoch 2
# Train Loss: 0.0845, Train Acc: 0.9734
# Val Loss: 0.0774, Val Acc: 0.9774
# Epoch 3
# Train Loss: 0.0835, Train Acc: 0.9742
# Val Loss: 0.0762, Val Acc: 0.9778
# Epoch 4
# Train Loss: 0.0793, Train Acc: 0.9751
# Val Loss: 0.0870, Val Acc: 0.9739
# Epoch 5
# Train Loss: 0.0795, Train Acc: 0.9755
# Val Loss: 0.0749, Val Acc: 0.9771
# Epoch 6
# Train Loss: 0.0781, Train Acc: 0.9765
# Val Loss: 0.0780, Val Acc: 0.9768
# Epoch 7
# Train Loss: 0.0742, Train Acc: 0.9775
# Val Loss: 0.0837, Val Acc: 0.9731
# Epoch 8
# Train Loss: 0.0743, Train Acc: 0.9771
# Val Loss: 0.0828, Val Acc: 0.9740
# Epoch 9
# Train Loss: 0.0712, Train Acc: 0.9784
# Val Loss: 0.0853, Val Acc: 0.9744
# Epoch 10
# Train Loss: 0.0731, Train Acc: 0.9783
# Val Loss: 0.0751, Val Acc: 0.9770
# Fold 3
# Epoch 1
# Train Loss: 0.0743, Train Acc: 0.9772
# Val Loss: 0.0642, Val Acc: 0.9794
# Epoch 2
# Train Loss: 0.0741, Train Acc: 0.9770
# Val Loss: 0.0666, Val Acc: 0.9784
# Epoch 3
# Train Loss: 0.0670, Train Acc: 0.9794
# Val Loss: 0.0748, Val Acc: 0.9773
# Epoch 4
# Train Loss: 0.0684, Train Acc: 0.9786
# Val Loss: 0.0719, Val Acc: 0.9774
# Epoch 5
# Train Loss: 0.0707, Train Acc: 0.9788
# Val Loss: 0.0740, Val Acc: 0.9772
# Epoch 6
# Train Loss: 0.0651, Train Acc: 0.9803
# Val Loss: 0.0783, Val Acc: 0.9768
# Epoch 7
# Train Loss: 0.0679, Train Acc: 0.9797
# Val Loss: 0.0721, Val Acc: 0.9795
# Epoch 8
# Train Loss: 0.0656, Train Acc: 0.9801
# Val Loss: 0.0712, Val Acc: 0.9784
# Epoch 9
# Train Loss: 0.0664, Train Acc: 0.9795
# Val Loss: 0.0683, Val Acc: 0.9785
# Epoch 10
# Train Loss: 0.0640, Train Acc: 0.9806
# Val Loss: 0.0772, Val Acc: 0.9778
# Fold 4
# Epoch 1
# Train Loss: 0.0659, Train Acc: 0.9802
# Val Loss: 0.0636, Val Acc: 0.9805
# Epoch 2
# Train Loss: 0.0625, Train Acc: 0.9804
# Val Loss: 0.0721, Val Acc: 0.9786
# Epoch 3
# Train Loss: 0.0614, Train Acc: 0.9812
# Val Loss: 0.0771, Val Acc: 0.9771
# Epoch 4
# Train Loss: 0.0618, Train Acc: 0.9814
# Val Loss: 0.0745, Val Acc: 0.9787
# Epoch 5
# Train Loss: 0.0615, Train Acc: 0.9811
# Val Loss: 0.0741, Val Acc: 0.9776
# Epoch 6
# Train Loss: 0.0628, Train Acc: 0.9809
# Val Loss: 0.0696, Val Acc: 0.9782
# Epoch 7
# Train Loss: 0.0612, Train Acc: 0.9816
# Val Loss: 0.0848, Val Acc: 0.9739
# Epoch 8
# Train Loss: 0.0597, Train Acc: 0.9816
# Val Loss: 0.0821, Val Acc: 0.9760
# Epoch 9
# Train Loss: 0.0605, Train Acc: 0.9814
# Val Loss: 0.0784, Val Acc: 0.9770
# Epoch 10
# Train Loss: 0.0593, Train Acc: 0.9819
# Val Loss: 0.0823, Val Acc: 0.9779
# Fold 5
# Epoch 1
# Train Loss: 0.0626, Train Acc: 0.9815
# Val Loss: 0.0622, Val Acc: 0.9803
# Epoch 2
# Train Loss: 0.0625, Train Acc: 0.9808
# Val Loss: 0.0630, Val Acc: 0.9795
# Epoch 3
# Train Loss: 0.0599, Train Acc: 0.9820
# Val Loss: 0.0572, Val Acc: 0.9834
# Epoch 4
# Train Loss: 0.0599, Train Acc: 0.9822
# Val Loss: 0.0624, Val Acc: 0.9812
# Epoch 5
# Train Loss: 0.0621, Train Acc: 0.9807
# Val Loss: 0.0624, Val Acc: 0.9803
# Epoch 6
# Train Loss: 0.0581, Train Acc: 0.9823
# Val Loss: 0.0638, Val Acc: 0.9823
# Epoch 7
# Train Loss: 0.0597, Train Acc: 0.9817
# Val Loss: 0.0637, Val Acc: 0.9818
# Epoch 8
# Train Loss: 0.0589, Train Acc: 0.9817
# Val Loss: 0.0662, Val Acc: 0.9801
# Epoch 9
# Train Loss: 0.0595, Train Acc: 0.9813
# Val Loss: 0.0630, Val Acc: 0.9808
# Epoch 10
# ...
# Val Loss: 0.0611, Val Acc: 0.9807
# Epoch 3
# Train Loss: 0.0591, Train Acc: 0.9812
# Val Loss: 0.0623, Val Acc: 0.9801
# Epoch 4
# Train Loss: 0.0571, Train Acc: 0.9822
# Val Loss: 0.0646, Val Acc: 0.9791
# Epoch 5
# Train Loss: 0.0562, Train Acc: 0.9826
# Val Loss: 0.0603, Val Acc: 0.9799
# Epoch 6
# Train Loss: 0.0560, Train Acc: 0.9811
# Val Loss: 0.0625, Val Acc: 0.9798
# Epoch 7
# Train Loss: 0.0558, Train Acc: 0.9822
# Val Loss: 0.0609, Val Acc: 0.9811
# Epoch 8
# Train Loss: 0.0545, Train Acc: 0.9824
# Val Loss: 0.0643, Val Acc: 0.9800
# Epoch 9
# Train Loss: 0.0510, Train Acc: 0.9836
# Val Loss: 0.0618, Val Acc: 0.9813
# Epoch 10
# Train Loss: 0.0504, Train Acc: 0.9836
# Val Loss: 0.0577, Val Acc: 0.9818
# Fold 4
# Epoch 1
# Train Loss: 0.0517, Train Acc: 0.9832
# Val Loss: 0.0472, Val Acc: 0.9849
# Epoch 2
# Train Loss: 0.0532, Train Acc: 0.9827
# Val Loss: 0.0501, Val Acc: 0.9838
# Epoch 3
# Train Loss: 0.0502, Train Acc: 0.9836
# Val Loss: 0.0480, Val Acc: 0.9846
# Epoch 4
# Train Loss: 0.0482, Train Acc: 0.9846
# Val Loss: 0.0486, Val Acc: 0.9850
# Epoch 5
# Train Loss: 0.0489, Train Acc: 0.9834
# Val Loss: 0.0488, Val Acc: 0.9833
# Epoch 6
# Train Loss: 0.0483, Train Acc: 0.9840
# Val Loss: 0.0498, Val Acc: 0.9850
# Epoch 7
# Train Loss: 0.0480, Train Acc: 0.9842
# Val Loss: 0.0504, Val Acc: 0.9842
# Epoch 8
# Train Loss: 0.0448, Train Acc: 0.9853
# Val Loss: 0.0538, Val Acc: 0.9821
# Epoch 9
# Train Loss: 0.0445, Train Acc: 0.9855
# Val Loss: 0.0468, Val Acc: 0.9857
# Epoch 10
# Train Loss: 0.0437, Train Acc: 0.9857
# Val Loss: 0.0519, Val Acc: 0.9845
# Fold 5
# Epoch 1
# Train Loss: 0.0462, Train Acc: 0.9847
# Val Loss: 0.0442, Val Acc: 0.9865
# Epoch 2
# Train Loss: 0.0452, Train Acc: 0.9851
# Val Loss: 0.0438, Val Acc: 0.9850
# Epoch 3
# Train Loss: 0.0467, Train Acc: 0.9850
# Val Loss: 0.0450, Val Acc: 0.9857
# Epoch 4
# Train Loss: 0.0451, Train Acc: 0.9851
# Val Loss: 0.0436, Val Acc: 0.9859
# Epoch 5
# Train Loss: 0.0436, Train Acc: 0.9862
# Val Loss: 0.0422, Val Acc: 0.9855
# Epoch 6
# Train Loss: 0.0450, Train Acc: 0.9851
# Val Loss: 0.0435, Val Acc: 0.9862
# Epoch 7
# Train Loss: 0.0431, Train Acc: 0.9862
# Val Loss: 0.0398, Val Acc: 0.9857
# Epoch 8
# Train Loss: 0.0427, Train Acc: 0.9859
# Val Loss: 0.0406, Val Acc: 0.9862
# Epoch 9
# Train Loss: 0.0423, Train Acc: 0.9865
# Val Loss: 0.0456, Val Acc: 0.9851
# Epoch 10
# [I 2025-02-17 00:48:59,477] Trial 16 finished with value: 0.09771250000000002 and parameters: {'fc1_size': 256, 'fc2_size': 32, 'optimizer': 'Adagrad', 'lr': 0.07601906884271327, 'batch_size': 96}. Best is trial 15 with value: 0.098059.
# Train Loss: 0.0413, Train Acc: 0.9864
# Val Loss: 0.0465, Val Acc: 0.9853
# Average Train Loss: 0.7212, Average Train Acc: 0.7533
# Average Val Loss: 0.7153, Average Val Acc: 0.7553
# Fold 1
# Epoch 1
# Train Loss: 0.3486, Train Acc: 0.8883
# Val Loss: 0.1716, Val Acc: 0.9462
# Epoch 2
# Train Loss: 0.1368, Train Acc: 0.9577
# Val Loss: 0.1330, Val Acc: 0.9575
# Epoch 3
# Train Loss: 0.1094, Train Acc: 0.9655
# Val Loss: 0.1139, Val Acc: 0.9642
# Epoch 4
# Train Loss: 0.0924, Train Acc: 0.9703
# Val Loss: 0.1062, Val Acc: 0.9665
# Epoch 5
# Train Loss: 0.0889, Train Acc: 0.9716
# Val Loss: 0.0985, Val Acc: 0.9699
# Epoch 6
# Train Loss: 0.0801, Train Acc: 0.9740
# Val Loss: 0.0929, Val Acc: 0.9698
# Epoch 7
# Train Loss: 0.0744, Train Acc: 0.9769
# Val Loss: 0.0917, Val Acc: 0.9730
# Epoch 8
# Train Loss: 0.0732, Train Acc: 0.9762
# Val Loss: 0.0879, Val Acc: 0.9732
# Epoch 9
# Train Loss: 0.0677, Train Acc: 0.9780
# Val Loss: 0.0832, Val Acc: 0.9755
# Epoch 10
# Train Loss: 0.0634, Train Acc: 0.9792
# Val Loss: 0.0764, Val Acc: 0.9760
# Fold 2
# Epoch 1
# Train Loss: 0.0683, Train Acc: 0.9782
# Val Loss: 0.0612, Val Acc: 0.9815
# Epoch 2
# Train Loss: 0.0630, Train Acc: 0.9798
# Val Loss: 0.0544, Val Acc: 0.9831
# Epoch 3
# Train Loss: 0.0617, Train Acc: 0.9804
# Val Loss: 0.0553, Val Acc: 0.9827
# Epoch 4
# Train Loss: 0.0579, Train Acc: 0.9817
# Val Loss: 0.0567, Val Acc: 0.9823
# Epoch 5
# Train Loss: 0.0579, Train Acc: 0.9818
# Val Loss: 0.0606, Val Acc: 0.9793
# Epoch 6
# Train Loss: 0.0567, Train Acc: 0.9813
# Val Loss: 0.0559, Val Acc: 0.9818
# Epoch 7
# Train Loss: 0.0526, Train Acc: 0.9828
# Val Loss: 0.0555, Val Acc: 0.9824
# Epoch 8
# Train Loss: 0.0543, Train Acc: 0.9822
# Val Loss: 0.0570, Val Acc: 0.9818
# Epoch 9
# Train Loss: 0.0515, Train Acc: 0.9835
# Val Loss: 0.0558, Val Acc: 0.9817
# Epoch 10
# Train Loss: 0.0517, Train Acc: 0.9842
# Val Loss: 0.0532, Val Acc: 0.9831
# Fold 3
# Epoch 1
# Train Loss: 0.0510, Train Acc: 0.9832
# Val Loss: 0.0438, Val Acc: 0.9866
# Epoch 2
# Train Loss: 0.0506, Train Acc: 0.9838
# Val Loss: 0.0458, Val Acc: 0.9851
# Epoch 3
# Train Loss: 0.0503, Train Acc: 0.9831
# Val Loss: 0.0473, Val Acc: 0.9851
# Epoch 4
# Train Loss: 0.0495, Train Acc: 0.9839
# Val Loss: 0.0437, Val Acc: 0.9869
# Epoch 5
# Train Loss: 0.0469, Train Acc: 0.9848
# Val Loss: 0.0440, Val Acc: 0.9850
# Epoch 6
# Train Loss: 0.0464, Train Acc: 0.9842
# Val Loss: 0.0449, Val Acc: 0.9868
# Epoch 7
# Train Loss: 0.0451, Train Acc: 0.9851
# Val Loss: 0.0428, Val Acc: 0.9860
# Epoch 8
# Train Loss: 0.0433, Train Acc: 0.9859
# Val Loss: 0.0474, Val Acc: 0.9838
# Epoch 9
# Train Loss: 0.0432, Train Acc: 0.9860
# Val Loss: 0.0490, Val Acc: 0.9833
# Epoch 10
# Train Loss: 0.0452, Train Acc: 0.9854
# Val Loss: 0.0461, Val Acc: 0.9843
# Fold 4
# Epoch 1
# Train Loss: 0.0447, Train Acc: 0.9848
# Val Loss: 0.0395, Val Acc: 0.9868
# Epoch 2
# Train Loss: 0.0421, Train Acc: 0.9858
# Val Loss: 0.0412, Val Acc: 0.9861
# Epoch 3
# Train Loss: 0.0430, Train Acc: 0.9857
# Val Loss: 0.0416, Val Acc: 0.9861
# Epoch 4
# Train Loss: 0.0398, Train Acc: 0.9870
# Val Loss: 0.0429, Val Acc: 0.9858
# Epoch 5
# Train Loss: 0.0415, Train Acc: 0.9863
# Val Loss: 0.0404, Val Acc: 0.9858
# Epoch 6
# Train Loss: 0.0399, Train Acc: 0.9862
# Val Loss: 0.0400, Val Acc: 0.9858
# Epoch 7
# Train Loss: 0.0412, Train Acc: 0.9865
# Val Loss: 0.0409, Val Acc: 0.9867
# Epoch 8
# Train Loss: 0.0381, Train Acc: 0.9880
# Val Loss: 0.0411, Val Acc: 0.9866
# Epoch 9
# Train Loss: 0.0384, Train Acc: 0.9875
# Val Loss: 0.0408, Val Acc: 0.9862
# Epoch 10
# Train Loss: 0.0371, Train Acc: 0.9884
# Val Loss: 0.0419, Val Acc: 0.9855
# Fold 5
# Epoch 1
# Train Loss: 0.0393, Train Acc: 0.9872
# Val Loss: 0.0368, Val Acc: 0.9871
# Epoch 2
# Train Loss: 0.0401, Train Acc: 0.9859
# Val Loss: 0.0365, Val Acc: 0.9874
# Epoch 3
# Train Loss: 0.0368, Train Acc: 0.9875
# Val Loss: 0.0334, Val Acc: 0.9888
# Epoch 4
# Train Loss: 0.0376, Train Acc: 0.9870
# Val Loss: 0.0399, Val Acc: 0.9877
# Epoch 5
# Train Loss: 0.0380, Train Acc: 0.9879
# Val Loss: 0.0350, Val Acc: 0.9869
# Epoch 6
# Train Loss: 0.0360, Train Acc: 0.9888
# Val Loss: 0.0383, Val Acc: 0.9878
# Epoch 7
# Train Loss: 0.0358, Train Acc: 0.9884
# Val Loss: 0.0351, Val Acc: 0.9896
# Epoch 8
# Train Loss: 0.0338, Train Acc: 0.9890
# Val Loss: 0.0400, Val Acc: 0.9865
# Epoch 9
# Train Loss: 0.0353, Train Acc: 0.9883
# Val Loss: 0.0363, Val Acc: 0.9877
# Epoch 10
# [I 2025-02-17 00:57:41,489] Trial 17 finished with value: 0.09816516666666669 and parameters: {'fc1_size': 256, 'fc2_size': 48, 'optimizer': 'Adagrad', 'lr': 0.021163235165688424, 'batch_size': 96}. Best is trial 17 with value: 0.09816516666666669.
# Train Loss: 0.0359, Train Acc: 0.9880
# Val Loss: 0.0379, Val Acc: 0.9875
# Average Train Loss: 0.6844, Average Train Acc: 0.7660
# Average Val Loss: 0.6788, Average Val Acc: 0.7679
# Fold 1
# Epoch 1
# Train Loss: 0.2655, Train Acc: 0.9160
# Val Loss: 0.1479, Val Acc: 0.9520
# Epoch 2
# Train Loss: 0.1260, Train Acc: 0.9603
# Val Loss: 0.1161, Val Acc: 0.9632
# Epoch 3
# Train Loss: 0.1042, Train Acc: 0.9670
# Val Loss: 0.1016, Val Acc: 0.9673
# Epoch 4
# Train Loss: 0.0900, Train Acc: 0.9719
# Val Loss: 0.0942, Val Acc: 0.9698
# Epoch 5
# Train Loss: 0.0832, Train Acc: 0.9737
# Val Loss: 0.0845, Val Acc: 0.9736
# Epoch 6
# Train Loss: 0.0765, Train Acc: 0.9762
# Val Loss: 0.0842, Val Acc: 0.9748
# Epoch 7
# Train Loss: 0.0727, Train Acc: 0.9765
# Val Loss: 0.0741, Val Acc: 0.9770
# Epoch 8
# Train Loss: 0.0699, Train Acc: 0.9769
# Val Loss: 0.0770, Val Acc: 0.9750
# Epoch 9
# Train Loss: 0.0638, Train Acc: 0.9784
# Val Loss: 0.0773, Val Acc: 0.9762
# Epoch 10
# Train Loss: 0.0647, Train Acc: 0.9795
# Val Loss: 0.0730, Val Acc: 0.9768
# Fold 2
# Epoch 1
# Train Loss: 0.0634, Train Acc: 0.9801
# Val Loss: 0.0554, Val Acc: 0.9825
# Epoch 2
# Train Loss: 0.0595, Train Acc: 0.9808
# Val Loss: 0.0556, Val Acc: 0.9824
# Epoch 3
# Train Loss: 0.0580, Train Acc: 0.9813
# Val Loss: 0.0607, Val Acc: 0.9793
# Epoch 4
# Train Loss: 0.0565, Train Acc: 0.9811
# Val Loss: 0.0567, Val Acc: 0.9815
# Epoch 5
# Train Loss: 0.0556, Train Acc: 0.9823
# Val Loss: 0.0567, Val Acc: 0.9818
# Epoch 6
# Train Loss: 0.0531, Train Acc: 0.9825
# Val Loss: 0.0556, Val Acc: 0.9818
# Epoch 7
# Train Loss: 0.0521, Train Acc: 0.9828
# Val Loss: 0.0571, Val Acc: 0.9819
# Epoch 8
# Train Loss: 0.0489, Train Acc: 0.9843
# Val Loss: 0.0572, Val Acc: 0.9812
# Epoch 9
# Train Loss: 0.0452, Train Acc: 0.9854
# Val Loss: 0.0523, Val Acc: 0.9814
# Epoch 10
# Train Loss: 0.0471, Train Acc: 0.9843
# Val Loss: 0.0539, Val Acc: 0.9829
# Fold 3
# Epoch 1
# Train Loss: 0.0489, Train Acc: 0.9845
# Val Loss: 0.0464, Val Acc: 0.9850
# Epoch 2
# Train Loss: 0.0491, Train Acc: 0.9835
# Val Loss: 0.0491, Val Acc: 0.9848
# Epoch 3
# Train Loss: 0.0452, Train Acc: 0.9856
# Val Loss: 0.0474, Val Acc: 0.9843
# Epoch 4
# Train Loss: 0.0460, Train Acc: 0.9845
# Val Loss: 0.0465, Val Acc: 0.9852
# Epoch 5
# Train Loss: 0.0442, Train Acc: 0.9860
# Val Loss: 0.0473, Val Acc: 0.9858
# Epoch 6
# Train Loss: 0.0455, Train Acc: 0.9853
# Val Loss: 0.0472, Val Acc: 0.9852
# Epoch 7
# Train Loss: 0.0412, Train Acc: 0.9866
# Val Loss: 0.0471, Val Acc: 0.9853
# Epoch 8
# Train Loss: 0.0410, Train Acc: 0.9866
# Val Loss: 0.0455, Val Acc: 0.9853
# Epoch 9
# Train Loss: 0.0418, Train Acc: 0.9864
# Val Loss: 0.0472, Val Acc: 0.9848
# Epoch 10
# Train Loss: 0.0406, Train Acc: 0.9870
# Val Loss: 0.0491, Val Acc: 0.9852
# Fold 4
# Epoch 1
# Train Loss: 0.0427, Train Acc: 0.9864
# Val Loss: 0.0334, Val Acc: 0.9891
# Epoch 2
# Train Loss: 0.0393, Train Acc: 0.9870
# Val Loss: 0.0374, Val Acc: 0.9878
# Epoch 3
# Train Loss: 0.0412, Train Acc: 0.9868
# Val Loss: 0.0381, Val Acc: 0.9875
# Epoch 4
# Train Loss: 0.0389, Train Acc: 0.9878
# Val Loss: 0.0365, Val Acc: 0.9875
# Epoch 5
# Train Loss: 0.0409, Train Acc: 0.9864
# Val Loss: 0.0357, Val Acc: 0.9888
# Epoch 6
# Train Loss: 0.0387, Train Acc: 0.9872
# Val Loss: 0.0399, Val Acc: 0.9873
# Epoch 7
# Train Loss: 0.0389, Train Acc: 0.9864
# Val Loss: 0.0384, Val Acc: 0.9887
# Epoch 8
# Train Loss: 0.0388, Train Acc: 0.9875
# Val Loss: 0.0372, Val Acc: 0.9888
# Epoch 9
# Train Loss: 0.0360, Train Acc: 0.9880
# Val Loss: 0.0367, Val Acc: 0.9882
# Epoch 10
# Train Loss: 0.0376, Train Acc: 0.9876
# Val Loss: 0.0419, Val Acc: 0.9872
# Fold 5
# Epoch 1
# Train Loss: 0.0396, Train Acc: 0.9871
# Val Loss: 0.0330, Val Acc: 0.9892
# Epoch 2
# Train Loss: 0.0376, Train Acc: 0.9877
# Val Loss: 0.0330, Val Acc: 0.9892
# Epoch 3
# Train Loss: 0.0358, Train Acc: 0.9882
# Val Loss: 0.0294, Val Acc: 0.9898
# Epoch 4
# Train Loss: 0.0366, Train Acc: 0.9880
# Val Loss: 0.0325, Val Acc: 0.9882
# Epoch 5
# Train Loss: 0.0354, Train Acc: 0.9884
# Val Loss: 0.0350, Val Acc: 0.9890
# Epoch 6
# Train Loss: 0.0326, Train Acc: 0.9890
# Val Loss: 0.0402, Val Acc: 0.9865
# Epoch 7
# Train Loss: 0.0348, Train Acc: 0.9891
# Val Loss: 0.0354, Val Acc: 0.9877
# Epoch 8
# Train Loss: 0.0362, Train Acc: 0.9883
# Val Loss: 0.0332, Val Acc: 0.9891
# Epoch 9
# Train Loss: 0.0341, Train Acc: 0.9891
# Val Loss: 0.0325, Val Acc: 0.9899
# Epoch 10
# [I 2025-02-17 01:07:19,255] Trial 18 finished with value: 0.09828366666666663 and parameters: {'fc1_size': 256, 'fc2_size': 48, 'optimizer': 'Adagrad', 'lr': 0.025374308187755247, 'batch_size': 32}. Best is trial 18 with value: 0.09828366666666663.
# Train Loss: 0.0338, Train Acc: 0.9888
# Val Loss: 0.0344, Val Acc: 0.9888
# Average Train Loss: 0.6513, Average Train Acc: 0.7774
# Average Val Loss: 0.6459, Average Val Acc: 0.7792
# Fold 1
# Epoch 1
# Train Loss: 0.2537, Train Acc: 0.9185
# Val Loss: 0.1597, Val Acc: 0.9501
# Epoch 2
# Train Loss: 0.1281, Train Acc: 0.9590
# Val Loss: 0.1193, Val Acc: 0.9619
# Epoch 3
# Train Loss: 0.1034, Train Acc: 0.9672
# Val Loss: 0.1079, Val Acc: 0.9648
# Epoch 4
# Train Loss: 0.0906, Train Acc: 0.9716
# Val Loss: 0.0972, Val Acc: 0.9701
# Epoch 5
# Train Loss: 0.0844, Train Acc: 0.9731
# Val Loss: 0.0904, Val Acc: 0.9716
# Epoch 6
# Train Loss: 0.0770, Train Acc: 0.9752
# Val Loss: 0.0926, Val Acc: 0.9701
# Epoch 7
# Train Loss: 0.0727, Train Acc: 0.9771
# Val Loss: 0.0795, Val Acc: 0.9748
# Epoch 8
# Train Loss: 0.0689, Train Acc: 0.9780
# Val Loss: 0.0815, Val Acc: 0.9748
# Epoch 9
# Train Loss: 0.0688, Train Acc: 0.9778
# Val Loss: 0.0812, Val Acc: 0.9749
# Epoch 10
# Train Loss: 0.0648, Train Acc: 0.9792
# Val Loss: 0.0790, Val Acc: 0.9756
# Fold 2
# Epoch 1
# Train Loss: 0.0676, Train Acc: 0.9783
# Val Loss: 0.0618, Val Acc: 0.9799
# Epoch 2
# Train Loss: 0.0617, Train Acc: 0.9807
# Val Loss: 0.0615, Val Acc: 0.9792
# Epoch 3
# Train Loss: 0.0618, Train Acc: 0.9805
# Val Loss: 0.0608, Val Acc: 0.9811
# Epoch 4
# Train Loss: 0.0581, Train Acc: 0.9814
# Val Loss: 0.0618, Val Acc: 0.9816
# Epoch 5
# Train Loss: 0.0538, Train Acc: 0.9828
# Val Loss: 0.0591, Val Acc: 0.9808
# Epoch 6
# Train Loss: 0.0565, Train Acc: 0.9818
# Val Loss: 0.0609, Val Acc: 0.9798
# Epoch 7
# Train Loss: 0.0535, Train Acc: 0.9828
# Val Loss: 0.0575, Val Acc: 0.9808
# Epoch 8
# Train Loss: 0.0529, Train Acc: 0.9830
# Val Loss: 0.0609, Val Acc: 0.9802
# Epoch 9
# Train Loss: 0.0527, Train Acc: 0.9829
# Val Loss: 0.0611, Val Acc: 0.9802
# Epoch 10
# Train Loss: 0.0515, Train Acc: 0.9835
# Val Loss: 0.0592, Val Acc: 0.9814
# Fold 3
# Epoch 1
# Train Loss: 0.0538, Train Acc: 0.9829
# Val Loss: 0.0433, Val Acc: 0.9867
# Epoch 2
# Train Loss: 0.0509, Train Acc: 0.9835
# Val Loss: 0.0455, Val Acc: 0.9856
# Epoch 3
# Train Loss: 0.0507, Train Acc: 0.9830
# Val Loss: 0.0448, Val Acc: 0.9858
# Epoch 4
# Train Loss: 0.0495, Train Acc: 0.9840
# Val Loss: 0.0499, Val Acc: 0.9841
# Epoch 5
# Train Loss: 0.0493, Train Acc: 0.9842
# Val Loss: 0.0484, Val Acc: 0.9844
# Epoch 6
# Train Loss: 0.0476, Train Acc: 0.9848
# Val Loss: 0.0445, Val Acc: 0.9863
# Epoch 7
# Train Loss: 0.0450, Train Acc: 0.9851
# Val Loss: 0.0504, Val Acc: 0.9855
# Epoch 8
# Train Loss: 0.0441, Train Acc: 0.9856
# Val Loss: 0.0478, Val Acc: 0.9858
# Epoch 9
# Train Loss: 0.0443, Train Acc: 0.9854
# Val Loss: 0.0478, Val Acc: 0.9850
# Epoch 10
# Train Loss: 0.0448, Train Acc: 0.9852
# Val Loss: 0.0496, Val Acc: 0.9839
# Fold 4
# Epoch 1
# Train Loss: 0.0460, Train Acc: 0.9853
# Val Loss: 0.0406, Val Acc: 0.9879
# Epoch 2
# Train Loss: 0.0445, Train Acc: 0.9854
# Val Loss: 0.0370, Val Acc: 0.9875
# Epoch 3
# Train Loss: 0.0452, Train Acc: 0.9854
# Val Loss: 0.0355, Val Acc: 0.9882
# Epoch 4
# Train Loss: 0.0442, Train Acc: 0.9858
# Val Loss: 0.0375, Val Acc: 0.9889
# Epoch 5
# Train Loss: 0.0426, Train Acc: 0.9861
# Val Loss: 0.0456, Val Acc: 0.9858
# Epoch 6
# Train Loss: 0.0426, Train Acc: 0.9862
# Val Loss: 0.0408, Val Acc: 0.9870
# Epoch 7
# Train Loss: 0.0411, Train Acc: 0.9867
# Val Loss: 0.0401, Val Acc: 0.9874
# Epoch 8
# Train Loss: 0.0405, Train Acc: 0.9868
# Val Loss: 0.0446, Val Acc: 0.9854
# Epoch 9
# Train Loss: 0.0399, Train Acc: 0.9866
# Val Loss: 0.0396, Val Acc: 0.9874
# Epoch 10
# Train Loss: 0.0377, Train Acc: 0.9872
# Val Loss: 0.0387, Val Acc: 0.9872
# Fold 5
# Epoch 1
# Train Loss: 0.0399, Train Acc: 0.9874
# Val Loss: 0.0371, Val Acc: 0.9876
# Epoch 2
# Train Loss: 0.0402, Train Acc: 0.9867
# Val Loss: 0.0343, Val Acc: 0.9894
# Epoch 3
# Train Loss: 0.0399, Train Acc: 0.9868
# Val Loss: 0.0358, Val Acc: 0.9889
# Epoch 4
# Train Loss: 0.0377, Train Acc: 0.9876
# Val Loss: 0.0333, Val Acc: 0.9889
# Epoch 5
# Train Loss: 0.0395, Train Acc: 0.9872
# Val Loss: 0.0387, Val Acc: 0.9859
# Epoch 6
# Train Loss: 0.0390, Train Acc: 0.9875
# Val Loss: 0.0369, Val Acc: 0.9871
# Epoch 7
# Train Loss: 0.0398, Train Acc: 0.9869
# Val Loss: 0.0382, Val Acc: 0.9887
# Epoch 8
# Train Loss: 0.0391, Train Acc: 0.9870
# Val Loss: 0.0356, Val Acc: 0.9883
# Epoch 9
# Train Loss: 0.0384, Train Acc: 0.9869
# Val Loss: 0.0371, Val Acc: 0.9874
# Epoch 10
# [I 2025-02-17 01:16:57,329] Trial 19 finished with value: 0.09819733333333337 and parameters: {'fc1_size': 224, 'fc2_size': 48, 'optimizer': 'Adagrad', 'lr': 0.01707678659667944, 'batch_size': 32}. Best is trial 18 with value: 0.09828366666666663.
# Train Loss: 0.0369, Train Acc: 0.9880
# Val Loss: 0.0377, Val Acc: 0.9870
# Average Train Loss: 0.6216, Average Train Acc: 0.7876
# Average Val Loss: 0.6164, Average Val Acc: 0.7893
# Best objective value: 0.09828366666666663
# Best hyperparameters: {'fc1_size': 256, 'fc2_size': 48, 'optimizer': 'Adagrad', 'lr': 0.025374308187755247, 'batch_size': 32}
